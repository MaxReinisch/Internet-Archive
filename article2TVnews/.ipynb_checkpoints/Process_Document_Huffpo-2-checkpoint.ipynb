# %% [markdown]
# # This Project's aim is to recommend a tv-news clip based on a given article using a content filter recommender

# %% [markdown]
# # Summary of the project:
#
# #### Static structure
# To build this, we will need a DB of the possible recommendations. This will have features such as:
# - `Title`
#     - Used to display to user
# - `entities`
#     - A vector of the features for each video
# - `url`
#     - A link to the full segment
#
#
# #### Program
# 1. We will programatically scan an article and parse it for its own entity vector.
#     - NLP topic modeling needed
# 2. Then we will find cosine dist from the article to each news clip.
# 3. return the 3 closest clips.
#
# #### Notes:
# - Depending on the size of the DB, we probably won't want to go through each entry.  Maybe I can cluster closer clips and return the cluster
# - Probably want to use components as well.
# - News sources: BBC, CNN, Fox, RT, MSNBC, Huffpo, the guardian,
# - opencalais
# -

# %% [markdown]
# ## Imports

# %%
from sklearn.feature_extraction.text import CountVectorizer
import requests
from bs4 import BeautifulSoup

# %%
access_token = "cvTFhY53VXBYm5HO85weHPx346W05015"
calais_url = 'https://api.thomsonreuters.com/permid/calais'
headers = {'X-AG-Access-Token' : access_token, 'Content-Type' : 'text/raw', 'outputformat' : 'application/json'}

# %% [markdown]
# ## Scan article
# - request site
#     - found this api:https://newsapi.org/
#         - Can't search individual articles by url as far as I can tell.  Might be worth considering though for multiple news sources
#         - Doesn't return full article, only title and desc
# - find relevant info
#     - http://mallet.cs.umass.edu/index.php
#     - http://www.opencalais.com/
# - assemble corpus OR run search on archive.org

# %% [markdown]
# #### Requests

# %%
url = 'https://www.huffingtonpost.com/entry/kansas-democrat-brent-welder-ad_us_5b625d65e4b0b15aba9f9774'
header = {"Accept-Encoding": "gzip", "User-Agent": "Max-of-all-trades"}
res = requests.get(url, params=header )
res.status_code
# Out:
# 403

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %% [markdown]
# #### Parse

# %%
title = soup.find("h1", attrs={"class":"headline__title"}).text
title
# Out:
# "Alex Jones' Infowars Still Not Banned On App Stores, Instagram And Twitter"

# %%
subtitle = soup.find("div", attrs={"class":"headline__subtitle"}).text
subtitle
# Out:
# 'Companies like Spotify and Facebook have taken action, removing Infowars content.'

# %%
soup.find("a", attrs={"class": "author-card__link"}).text
# Out:
# '\n'

# %%
body = "\n\n".join(list(map(lambda x: x.text, soup.find("div", attrs={"class":"entry__text"}).find_all("div", attrs={"class":"content-list-component"}))))
print(body)
# Out:
# Apple and Google have both removed some Alex Jones content from some of their platforms, but his Infowars app is still available for download in both app stores and his accounts on Twitter and Instagram are still active.
#
# Listed under the “News” sections of the iOS App Store and the Google Play store, the Infowars app offers its subscribers livestreams and articles. It’s ranked as high as No. 23 among free news apps on Apple, according to CNN Money.
#
# Apple did remove some of Jones’ podcasts from iTunes, while YouTube, which is owned by Google, removed his channel.
#
# “Apple does not tolerate hate speech, and we have clear guidelines that creators and developers must follow to ensure we provide a safe environment for all of our users,” the company said in a statement. “Podcasts that violate these guidelines are removed from our directory making them no longer searchable or available for download or streaming. We believe in representing a wide range of views, so long as people are respectful to those with differing opinions.”
#
# A growing list of other tech companies ― including Spotify, Facebook, Stitcher and, most recently, LinkedIn and Pinterest ― have removed some of Jones’ content, saying it violated hate speech policies.
#
# Yet his accounts on Instagram, Twitter and Periscope (which is owned by Twitter) are still up and running, and several of his movies are still available on Amazon. Twitter said the content didn’t violate its guidelines.
#
#
# Instagram, which is owned by Facebook, did not immediately respond to a request for comment.
# Jones has responded to the shutdowns by slamming the social media platforms as “lying bullies.”
#
#
#
# “The war on your mind is in full swing as globalists remove outlets of liberty and truth, starting with the tip of the spear: Alex Jones,” a statement on his website read.
# Jones also appealed to President Donald Trump for help on Monday, asking him to make a bigger deal of the fact that the globalists and the Chinese were trying to steal the 2018 midterm elections.
# “If you come out before the midterms and make the censorship the big issue of them trying to steal the election. And if you make the fact we need an Internet Bill of Rights, and antitrust-busting on these companies, if they don’t back off right now,” Jones said.

# %%
response = requests.post(calais_url, data=body.encode('utf-8'), headers=headers, timeout=80)
print ('status code: %s' % response.status_code)
content = response.text
# print ('Results received: %s' % content)
# Out:
# status code: 200
# Results received: {"doc":{"info":{"calaisRequestID":"a42792bb-fbf5-5ca4-1652-0b6b1433558f","id":"http:\/\/id.opencalais.com\/0MdRcaNtg3q7SUqFG5fKQA","ontology":"http:\/\/mdaas-virtual-onecalais.int.thomsonreuters.com\/owlschema\/11.9\/onecalais.owl.allmetadata.xml","docId":"http:\/\/d.opencalais.com\/dochash-1\/002fcf23-1236-38e4-9fe2-1ec16bb33b4c","document":"Apple and Google have both removed some Alex Jones content from some of their platforms, but his Infowars app is still available for download in both app stores and his accounts on Twitter and Instagram are still active.\n\nListed under the “News” sections of the iOS App Store and the Google Play store, the Infowars app offers its subscribers livestreams and articles. It’s ranked as high as No. 23 among free news apps on Apple, according to CNN Money.\n\nApple did remove some of Jones’ podcasts from iTunes, while YouTube, which is owned by Google, removed his channel. \n\n“Apple does not tolerate hate speech, and we have clear guidelines that creators and developers must follow to ensure we provide a safe environment for all of our users,” the company said in a statement. “Podcasts that violate these guidelines are removed from our directory making them no longer searchable or available for download or streaming. We believe in representing a wide range of views, so long as people are respectful to those with differing opinions.” \n\nA growing list of other tech companies ― including Spotify, Facebook, Stitcher and, most recently, LinkedIn and Pinterest ― have removed some of Jones’ content, saying it violated hate speech policies. \n\nYet his accounts on Instagram, Twitter and Periscope (which is owned by Twitter) are still up and running, and several of his movies are still available on Amazon. Twitter said the content didn’t violate its guidelines.\n\n\nInstagram, which is owned by Facebook, did not immediately respond to a request for comment.\nJones has responded to the shutdowns by slamming the social media platforms as “lying bullies.” \n\n\n\n“The war on your mind is in full swing as globalists remove outlets of liberty and truth, starting with the tip of the spear: Alex Jones,” a statement on his website read.\nJones also appealed to President Donald Trump for help on Monday, asking him to make a bigger deal of the fact that the globalists and the Chinese were trying to steal the 2018 midterm elections.  \n“If you come out before the midterms and make the censorship the big issue of them trying to steal the election. And if you make the fact we need an Internet Bill of Rights, and antitrust-busting on these companies, if they don’t back off right now,” Jones said. \n","docTitle":"","docDate":"2018-08-09 22:02:48.952"},"meta":{"contentType":"text\/raw","processingVer":"AllMetadata","serverVersion":"OneCalais_11.9-RELEASE:14","stagsVer":"OneCalais_11.9-RELEASE-b10-2018-07-05_01:53:32","submissionDate":"2018-08-09 22:02:48.515","submitterCode":"0ca6a864-5659-789d-5f32-f365f695e757","signature":"digestalg-1|Ddz6ig8czeGRqd1GIsLmqwzU3OY=|C1Jr+nZ3c0avNOm+OqOm+5BfRNgXPH48CcPehbUI8YTYCEtJP2ahCg==","language":"English"}},"http:\/\/d.opencalais.com\/dochash-1\/002fcf23-1236-38e4-9fe2-1ec16bb33b4c\/cat\/1":{"_typeGroup":"topics","forenduserdisplay":"false","score":0.957,"name":"Technology_Internet"},"http:\/\/d.opencalais.com\/dochash-1\/002fcf23-1236-38e4-9fe2-1ec16bb33b4c\/lid\/DefaultLangId":{"_typeGroup":"language","language":"http:\/\/d.opencalais.com\/lid\/DefaultLangId\/English","forenduserdisplay":"false","permid":"505062"},"http:\/\/d.opencalais.com\/dochash-1\/002fcf23-1236-38e4-9fe2-1ec16bb33b4c\/SocialTag\/1":{"_typeGroup":"socialTag","id":"http:\/\/d.opencalais.com\/dochash-1\/002fcf23-1236-38e4-9fe2-1ec16bb33b4c\/SocialTag\/1","socialTag":"http:\/\/d.opencalais.com\/genericHasher-1\/16293516-a848-3162-8f98-a310581b027d","forenduserdisplay":"true","name":"Software","importance":"1","originalValue":"Software"},"http:\/\/d.opencalais.com\/dochash-1\/002fcf23-1236- ...

# %%
import json

c = json.loads(content)
# Out:
# {'doc': {'info': {'calaisRequestID': 'a42792bb-fbf5-5ca4-1652-0b6b1433558f',
#    'docDate': '2018-08-09 22:02:48.952',
#    'docId': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c',
#    'docTitle': '',
#    'document': 'Apple and Google have both removed some Alex Jones content from some of their platforms, but his Infowars app is still available for download in both app stores and his accounts on Twitter and Instagram are still active.\n\nListed under the “News” sections of the iOS App Store and the Google Play store, the Infowars app offers its subscribers livestreams and articles. It’s ranked as high as No. 23 among free news apps on Apple, according to CNN Money.\n\nApple did remove some of Jones’ podcasts from iTunes, while YouTube, which is owned by Google, removed his channel. \n\n“Apple does not tolerate hate speech, and we have clear guidelines that creators and developers must follow to ensure we provide a safe environment for all of our users,” the company said in a statement. “Podcasts that violate these guidelines are removed from our directory making them no longer searchable or available for download or streaming. We believe in representing a wide range of views, so long as people are respectful to those with differing opinions.” \n\nA growing list of other tech companies ― including Spotify, Facebook, Stitcher and, most recently, LinkedIn and Pinterest ― have removed some of Jones’ content, saying it violated hate speech policies. \n\nYet his accounts on Instagram, Twitter and Periscope (which is owned by Twitter) are still up and running, and several of his movies are still available on Amazon. Twitter said the content didn’t violate its guidelines.\n\n\nInstagram, which is owned by Facebook, did not immediately respond to a request for comment.\nJones has responded to the shutdowns by slamming the social media platforms as “lying bullies.” \n\n\n\n“The war on your mind is in full swing as globalists remove outlets of liberty and truth, starting with the tip of the spear: Alex Jones,” a statement on his website read.\nJones also appealed to President Donald Trump for help on Monday, asking him to make a bigger deal of the fact that the globalists and the Chinese were trying to steal the 2018 midterm elections.  \n“If you come out before the midterms and make the censorship the big issue of them trying to steal the election. And if you make the fact we need an Internet Bill of Rights, and antitrust-busting on these companies, if they don’t back off right now,” Jones said. \n',
#    'id': 'http://id.opencalais.com/0MdRcaNtg3q7SUqFG5fKQA',
#    'ontology': 'http://mdaas-virtual-onecalais.int.thomsonreuters.com/owlschema/11.9/onecalais.owl.allmetadata.xml'},
#   'meta': {'contentType': 'text/raw',
#    'language': 'English',
#    'processingVer': 'AllMetadata',
#    'serverVersion': 'OneCalais_11.9-RELEASE:14',
#    'signature': 'digestalg-1|Ddz6ig8czeGRqd1GIsLmqwzU3OY=|C1Jr+nZ3c0avNOm+OqOm+5BfRNgXPH48CcPehbUI8YTYCEtJP2ahCg==',
#    'stagsVer': 'OneCalais_11.9-RELEASE-b10-2018-07-05_01:53:32',
#    'submissionDate': '2018-08-09 22:02:48.515',
#    'submitterCode': '0ca6a864-5659-789d-5f32-f365f695e757'}},
#  'http://d.opencalais.com/comphash-1/082c52ce-9eb3-320d-ac3b-f6be116a890f': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '0.89',
#    'dblookup': '0.0',
#    'resolution': '1.0',
#    'statisticalfeature': '0.799'},
#   'confidencelevel': '0.89',
#   'forenduserdisplay': 'false',
#   'instances': [{'detection': '[23 among free news apps on Apple, according to ]CNN[ Money.\n\nApple did remove some of Jones’ podcasts]',
#     'exact': 'CNN',
#     'length': 3,
#     'offset': 443,
#     'prefix': '23 among free news apps on Apple, according to ',
#     'suffix': ' Money.\n\nApple did remove some of Jones’ podcasts'}],
#   'name': 'CNN',
#   'nationality': 'N/A',
#   'recognizedas': 'name',
#   'relevance': 0,
#   'resolutions': [{'commonname': 'CNN',
#     'id': 'https://permid.org/1-4298210469',
#     'ispublic': 'false',
#     'name': 'CABLE NEWS NETWORK, INC.',
#     'permid': '4298210469',
#     'score': 1}]},
#  'http://d.opencalais.com/comphash-1/1076d1eb-4ea8-3d30-823a-db47764acc34': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '0.966',
#    'dblookup': '0.0',
#    'resolution': '0.9876603',
#    'statisticalfeature': '0.956'},
#   'confidencelevel': '0.966',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[download in both app stores and his accounts on ]Twitter[ and Instagram are still active.\n\nListed under]',
#     'exact': 'Twitter',
#     'length': 7,
#     'offset': 181,
#     'prefix': 'download in both app stores and his accounts on ',
#     'suffix': ' and Instagram are still active.\n\nListed under'},
#    {'detection': '[policies. \n\nYet his accounts on Instagram, ]Twitter[ and Periscope (which is owned by Twitter) are]',
#     'exact': 'Twitter',
#     'length': 7,
#     'offset': 1276,
#     'prefix': 'policies. \n\nYet his accounts on Instagram, ',
#     'suffix': ' and Periscope (which is owned by Twitter) are'},
#    {'detection': '[Twitter and Periscope (which is owned by ]Twitter[) are still up and running, and several of his]',
#     'exact': 'Twitter',
#     'length': 7,
#     'offset': 1317,
#     'prefix': 'Twitter and Periscope (which is owned by ',
#     'suffix': ') are still up and running, and several of his'},
#    {'detection': '[of his movies are still available on Amazon. ]Twitter[ said the content didn’t violate its]',
#     'exact': 'Twitter',
#     'length': 7,
#     'offset': 1409,
#     'prefix': 'of his movies are still available on Amazon. ',
#     'suffix': ' said the content didn’t violate its'}],
#   'name': 'Twitter',
#   'nationality': 'N/A',
#   'recognizedas': 'name',
#   'relevance': 0,
#   'resolutions': [{'commonname': 'Twitter',
#     'id': 'https://permid.org/1-4296301199',
#     'ispublic': 'true',
#     'name': 'TWITTER, INC.',
#     'permid': '4296301199',
#     'primaryric': 'TWTR.N',
#     'score': 0.9876603,
#     'ticker': 'TWTR'}]},
#  'http://d.opencalais.com/comphash-1/11aa8856-6a35-3107-9846-1ad190e5e313': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '1.0',
#    'dblookup': '0.0',
#    'resolution': '0.07729884',
#    'statisticalfeature': '0.916'},
#   'confidencelevel': '1.0',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[Stitcher and, most recently, LinkedIn and ]Pinterest[ ― have removed some of Jones’ content, saying it]',
#     'exact': 'Pinterest',
#     'length': 9,
#     'offset': 1153,
#     'prefix': 'Stitcher and, most recently, LinkedIn and ',
#     'suffix': ' ― have removed some of Jones’ content, saying it'}],
#   'name': 'Pinterest',
#   'nationality': 'N/A',
#   'recognizedas': 'name',
#   'relevance': 0.2,
#   'resolutions': [{'commonname': 'Pinterest',
#     'id': 'https://permid.org/1-5036190505',
#     'ispublic': 'false',
#     'name': 'COLD BREAW LABS INC.',
#     'permid': '5036190505',
#     'score': 0.07729884}]},
#  'http://d.opencalais.com/comphash-1/20706f4c-c437-390d-a697-cb3ba2ab23f0': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '1.0',
#    'dblookup': '0.0',
#    'resolution': '0.67992806',
#    'statisticalfeature': '0.905'},
#   'confidencelevel': '1.0',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[Spotify, Facebook, Stitcher and, most recently, ]LinkedIn[ and Pinterest ― have removed some of Jones’]',
#     'exact': 'LinkedIn',
#     'length': 8,
#     'offset': 1140,
#     'prefix': 'Spotify, Facebook, Stitcher and, most recently, ',
#     'suffix': ' and Pinterest ― have removed some of Jones’'}],
#   'name': 'LinkedIn',
#   'nationality': 'N/A',
#   'recognizedas': 'name',
#   'relevance': 0.2,
#   'resolutions': [{'commonname': 'LnkIn Corp',
#     'id': 'https://permid.org/1-4296977663',
#     'ispublic': 'false',
#     'name': 'LINKEDIN CORPORATION',
#     'permid': '4296977663',
#     'score': 0.67992806,
#     'ticker': 'LNKD'}]},
#  'http://d.opencalais.com/comphash-1/22b46470-b64a-3af3-949a-b461fad44500': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '0.995',
#    'dblookup': '0.0',
#    'resolution': '0.9931863',
#    'statisticalfeature': '0.933'},
#   'confidencelevel': '0.995',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[of other tech companies ― including Spotify, ]Facebook[, Stitcher and, most recently, LinkedIn and]',
#     'exact': 'Facebook',
#     'length': 8,
#     'offset': 1101,
#     'prefix': 'of other tech companies ― including Spotify, ',
#     'suffix': ', Stitcher and, most recently, LinkedIn and'},
#    {'detection': '[its guidelines.\n\n\nInstagram, which is owned by ]Facebook[, did not immediately respond to a request for]',
#     'exact': 'Facebook',
#     'length': 8,
#     'offset': 1496,
#     'prefix': 'its guidelines.\n\n\nInstagram, which is owned by ',
#     'suffix': ', did not immediately respond to a request for'}],
#   'name': 'Facebook',
#   'nationality': 'N/A',
#   'recognizedas': 'name',
#   'relevance': 0.2,
#   'resolutions': [{'commonname': 'Facebook',
#     'id': 'https://permid.org/1-4297297477',
#     'ispublic': 'true',
#     'name': 'FACEBOOK, INC.',
#     'permid': '4297297477',
#     'primaryric': 'FB.OQ',
#     'score': 0.9931863,
#     'ticker': 'FB'}]},
#  'http://d.opencalais.com/comphash-1/3b1045e3-d1d7-3505-81a3-3cbe045bbbd7': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '0.993',
#    'dblookup': '0.0',
#    'resolution': '0.99360967',
#    'statisticalfeature': '0.905'},
#   'confidencelevel': '0.993',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[ and several of his movies are still available on ]Amazon[. Twitter said the content didn’t violate its]',
#     'exact': 'Amazon',
#     'length': 6,
#     'offset': 1401,
#     'prefix': ' and several of his movies are still available on ',
#     'suffix': '. Twitter said the content didn’t violate its'}],
#   'name': 'Amazon',
#   'nationality': 'N/A',
#   'recognizedas': 'name',
#   'relevance': 0,
#   'resolutions': [{'commonname': 'Amazon.com',
#     'id': 'https://permid.org/1-4295905494',
#     'ispublic': 'true',
#     'name': 'AMAZON.COM, INC.',
#     'permid': '4295905494',
#     'primaryric': 'AMZN.OQ',
#     'score': 0.99360967,
#     'ticker': 'AMZN'}]},
#  'http://d.opencalais.com/comphash-1/705cd5cf-93e1-323c-8d4e-1ea3200d37e4': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '1.0',
#    'dblookup': '0.0',
#    'resolution': '0.9945767',
#    'statisticalfeature': '0.956'},
#   'confidencelevel': '1.0',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[]Apple[ and Google have both removed some Alex Jones]',
#     'exact': 'Apple',
#     'length': 5,
#     'offset': 0,
#     'suffix': ' and Google have both removed some Alex Jones'},
#    {'detection': '[ ranked as high as No. 23 among free news apps on ]Apple[, according to CNN Money.\n\nApple did remove some]',
#     'exact': 'Apple',
#     'length': 5,
#     'offset': 423,
#     'prefix': ' ranked as high as No. 23 among free news apps on ',
#     'suffix': ', according to CNN Money.\n\nApple did remove some'},
#    {'detection': '[news apps on Apple, according to CNN Money.\n\n]Apple[ did remove some of Jones’ podcasts from iTunes,]',
#     'exact': 'Apple',
#     'length': 5,
#     'offset': 455,
#     'prefix': 'news apps on Apple, according to CNN Money.\n\n',
#     'suffix': ' did remove some of Jones’ podcasts from iTunes,'},
#    {'detection': '[is owned by Google, removed his channel. \n\n“]Apple[ does not tolerate hate speech, and we have clear]',
#     'exact': 'Apple',
#     'length': 5,
#     'offset': 574,
#     'prefix': 'is owned by Google, removed his channel. \n\n“',
#     'suffix': ' does not tolerate hate speech, and we have clear'}],
#   'name': 'Apple',
#   'nationality': 'N/A',
#   'recognizedas': 'name',
#   'relevance': 0.5,
#   'resolutions': [{'commonname': 'Apple',
#     'id': 'https://permid.org/1-4295905573',
#     'ispublic': 'true',
#     'name': 'APPLE INC.',
#     'permid': '4295905573',
#     'primaryric': 'AAPL.OQ',
#     'score': 0.9945767,
#     'ticker': 'AAPL'}]},
#  'http://d.opencalais.com/comphash-1/82ad503f-95cf-330a-b82e-42f27fdd2c2c': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '1.0',
#    'dblookup': '0.0',
#    'resolution': '1.0',
#    'statisticalfeature': '0.644'},
#   'confidencelevel': '1.0',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[ growing list of other tech companies ― including ]Spotify[, Facebook, Stitcher and, most recently, LinkedIn]',
#     'exact': 'Spotify',
#     'length': 7,
#     'offset': 1092,
#     'prefix': ' growing list of other tech companies ― including ',
#     'suffix': ', Facebook, Stitcher and, most recently, LinkedIn'}],
#   'name': 'SPOTIFY',
#   'recognizedas': 'name',
#   'relevance': 0,
#   'resolutions': [{'commonname': 'Spotify Tech',
#     'id': 'https://permid.org/1-5037833896',
#     'ispublic': 'true',
#     'name': 'SPOTIFY TECHNOLOGY S.A.',
#     'permid': '5037833896',
#     'primaryric': 'SPOT.N',
#     'score': 1,
#     'ticker': 'SPOT'}]},
#  'http://d.opencalais.com/comphash-1/ab6c8681-759a-37ec-af62-b24109670f3d': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '0.795',
#    'dblookup': '0.0',
#    'resolution': '0.17043427',
#    'statisticalfeature': '0.922'},
#   'confidencelevel': '0.795',
#   'forenduserdisplay': 'false',
#   'instances': [{'detection': '[both app stores and his accounts on Twitter and ]Instagram[ are still active.\n\nListed under the “News”]',
#     'exact': 'Instagram',
#     'length': 9,
#     'offset': 193,
#     'prefix': 'both app stores and his accounts on Twitter and ',
#     'suffix': ' are still active.\n\nListed under the “News”'},
#    {'detection': '[hate speech policies. \n\nYet his accounts on ]Instagram[, Twitter and Periscope (which is owned by]',
#     'exact': 'Instagram',
#     'length': 9,
#     'offset': 1265,
#     'prefix': 'hate speech policies. \n\nYet his accounts on ',
#     'suffix': ', Twitter and Periscope (which is owned by'},
#    {'detection': '[the content didn’t violate its guidelines.\n\n\n]Instagram[, which is owned by Facebook, did not immediately]',
#     'exact': 'Instagram',
#     'length': 9,
#     'offset': 1467,
#     'prefix': 'the content didn’t violate its guidelines.\n\n\n',
#     'suffix': ', which is owned by Facebook, did not immediately'}],
#   'name': 'Instagram',
#   'nationality': 'N/A',
#   'recognizedas': 'name',
#   'relevance': 0,
#   'resolutions': [{'commonname': 'Instagram',
#     'id': 'https://permid.org/1-5037430461',
#     'ispublic': 'false',
#     'name': 'INSTAGRAM, INC.',
#     'permid': '5037430461',
#     'score': 0.17043427}]},
#  'http://d.opencalais.com/comphash-1/b054d269-db85-31cc-bd7e-f522a6809170': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '0.994',
#    'dblookup': '0.0',
#    'resolution': '0.18957536',
#    'statisticalfeature': '0.905'},
#   'confidencelevel': '0.994',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[some of Jones’ podcasts from iTunes, while ]YouTube[, which is owned by Google, removed his channel.]',
#     'exact': 'YouTube',
#     'length': 7,
#     'offset': 515,
#     'prefix': 'some of Jones’ podcasts from iTunes, while ',
#     'suffix': ', which is owned by Google, removed his channel.'}],
#   'name': 'YouTube',
#   'nationality': 'N/A',
#   'recognizedas': 'name',
#   'relevance': 0.2,
#   'resolutions': [{'commonname': 'YouTube, LLC',
#     'id': 'https://permid.org/1-4297403627',
#     'ispublic': 'false',
#     'name': 'YouTube, LLC',
#     'permid': '4297403627',
#     'score': 0.18957536}]},
#  'http://d.opencalais.com/comphash-1/c7172a98-4c8a-31a9-bfd4-ce426c8db3c0': {'_type': 'Company',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'confidence': {'aggregate': '0.999',
#    'dblookup': '0.0',
#    'resolution': '1.0',
#    'statisticalfeature': '0.71'},
#   'confidencelevel': '0.999',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[Apple and ]Google[ have both removed some Alex Jones content from]',
#     'exact': 'Google',
#     'length': 6,
#     'offset': 10,
#     'prefix': 'Apple and ',
#     'suffix': ' have both removed some Alex Jones content from'},
#    {'detection': '[from iTunes, while YouTube, which is owned by ]Google[, removed his channel. \n\n“Apple does not tolerate]',
#     'exact': 'Google',
#     'length': 6,
#     'offset': 542,
#     'prefix': 'from iTunes, while YouTube, which is owned by ',
#     'suffix': ', removed his channel. \n\n“Apple does not tolerate'}],
#   'name': 'Google',
#   'recognizedas': 'name',
#   'relevance': 0.2,
#   'resolutions': [{'commonname': 'Google',
#     'id': 'https://permid.org/1-4295899948',
#     'ispublic': 'false',
#     'name': 'GOOGLE LLC',
#     'permid': '4295899948',
#     'score': 1}]},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/ComponentVersions': {'_typeGroup': 'versions',
#   'version': ['DIY-Categorization-fnr-TRCS-prcng_3:20171117095241:20171117095241',
#    'DIY-Categorization-fnr-TRCS-curint-News:20180221133342:20180221133342',
#    'DIY-Categorization-fnr-TRCS-capx:20170627191152:20170627191152',
#    'DIY-Categorization-fnr-TRCS-job_cuts__rsh_nithish1___LAYOFS-Research:20180703093637:20180703093637',
#    'DIY-Categorization-fnr-TRCS-industry_consolidation_sai_rsh___INDMRG-Research:20180703113905:20180703113905',
#    'DIY-Categorization-fnr-TRCS-abs-News:20180321093043:20180321093043',
#    'DIY-Categorization-fnr-TRCS-meal___MEAL-News:20180716080238:20180716080238',
#    'DIY-Categorization-fnr-TRCS-cstcut_new-News:20180301140156:20180301140156',
#    'DIY-Categorization-fnr-TRCS-margnu:20171117095324:20171117095324',
#    'DIY-Categorization-fnr-TRCS-ta1___TA1-News:20180716090345:20180716090345',
#    'DIY-Categorization-fnr-TRCS-pgm___PGM-News:20180508065449:20180508065449',
#    'DIY-Categorization-fnr-TRCS-board1___BOARD1-News:20180622140843:20180622140843',
#    'Deals Index:201808092042:201808092042',
#    'DIY-Categorization-fnr-TRCS-cttl___CTTL-News:20180424161004:20180424161004',
#    'DIY-Categorization-fnr-TRCS-indx_stsale:20170323110805:20170323110805',
#    'DIY-Categorization-fnr-TRCS-margin_pressure_rsch_joel___MARGND-Research:20180518140643:20180518140643',
#    'DIY-Categorization-fnr-TRCS-comptn:20170621141739:20170621141739',
#    'DIY-Categorization-fnr-TRCS-childexploitation___KIDEXP-News:20180807075208:20180807075208',
#    'DIY-Categorization-fnr-TRCS-pricing_power_rsch_joel_new___PRCNG-Research:20180730092938:20180730092938',
#    'DIY-Categorization-fnr-TRCS-class_actions_rsch_joel___CLASS-Research:20180711122108:20180711122108',
#    'DIY-Categorization-fnr-TRCS-plcy___PLCY-News:20180416161629:20180416161629',
#    'DIY-Categorization-fnr-TRCS-financial_mismanagement3___FINMI-News:20180706115709:20180706115709',
#    'index-refineries:201808041820:201808041820',
#    'DIY-Categorization-fnr-TRCS-regs_buyb_new:20170509091609:20170509091609',
#    'DIY-Categorization-fnr-TRCS-int___INT-News:20180326113056:20180326113056',
#    'DIY-Categorization-fnr-TRCS-risk_infring_ola___M_1TC-News:20180605101139:20180605101139',
#    'DIY-Categorization-fnr-TRCS-pwrl___PWRL-News:20180716080357:20180716080357',
#    'config-physicalAssets-powerStations:826:826',

#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/Industry/5': {'_typeGroup': 'industry',
#   'forenduserdisplay': 'false',
#   'name': 'Search Engines',
#   'permid': '4294951196',
#   'rcscode': 'B:1805',
#   'relevance': 0.2},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/Industry/6': {'_typeGroup': 'industry',
#   'forenduserdisplay': 'false',
#   'name': 'Software - NEC',
#   'permid': '4294951205',
#   'rcscode': 'B:1796',
#   'relevance': 0},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/Industry/7': {'_typeGroup': 'industry',
#   'forenduserdisplay': 'false',
#   'name': 'Internet Services - NEC',
#   'permid': '4294951197',
#   'rcscode': 'B:1804',
#   'relevance': 0.2},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/1': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/1',
#   'importance': '1',
#   'name': 'Software',
#   'originalValue': 'Software',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/16293516-a848-3162-8f98-a310581b027d'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/10': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/10',
#   'importance': '2',
#   'name': 'InfoWars',
#   'originalValue': 'InfoWars',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/93a7d8a8-da53-30b0-8fe8-a3ca907ddcde'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/11': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/11',
#   'importance': '2',
#   'name': 'Stitcher Radio',
#   'originalValue': 'Stitcher Radio',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/92cfc040-f5e6-3357-ade6-c4951d665c7c'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/12': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/12',
#   'importance': '2',
#   'name': 'Facebook',
#   'originalValue': 'Facebook',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/b4f3a1a1-a94a-380c-8fb6-7d61fd802b3d'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/2': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/2',
#   'importance': '1',
#   'name': 'Computing',
#   'originalValue': 'Computing',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/4f9a3d55-33f5-3738-a2f7-3e9065a5a169'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/3': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/3',
#   'importance': '1',
#   'name': 'Digital media',
#   'originalValue': 'Digital media',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/771e4d9a-b0cd-37a2-bec6-6840c4cafab3'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/4': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/4',
#   'importance': '2',
#   'name': 'Social media',
#   'originalValue': 'Social media',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/26585b85-a498-31bb-abc9-70fdd3d7fb7c'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/5': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/5',
#   'importance': '2',
#   'name': 'Social networking services',
#   'originalValue': 'Social networking services',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/2021b3a9-eeac-3890-98ce-6367a7a57c7d'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/6': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/6',
#   'importance': '2',
#   'name': 'Universal Windows Platform apps',
#   'originalValue': 'Universal Windows Platform apps',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/03a060f0-38ee-3f7d-9a8b-ddd525e757f7'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/7': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/7',
#   'importance': '2',
#   'name': 'Photo sharing',
#   'originalValue': 'Photo sharing',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/37265ce8-0e57-377a-b088-9ec4d1a5e30e'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/8': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/8',
#   'importance': '2',
#   'name': 'E-commerce',
#   'originalValue': 'E-commerce',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/55c4fa6b-02ac-3970-964f-ce38d6d583e4'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/9': {'_typeGroup': 'socialTag',
#   'forenduserdisplay': 'true',
#   'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/9',
#   'importance': '2',
#   'name': 'Instagram',
#   'originalValue': 'Instagram',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/ab63b26b-ec99-34a0-8f6a-1d7c1c54a6c9'},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/cat/1': {'_typeGroup': 'topics',
#   'forenduserdisplay': 'false',
#   'name': 'Technology_Internet',
#   'score': 0.957},
#  'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/lid/DefaultLangId': {'_typeGroup': 'language',
#   'forenduserdisplay': 'false',
#   'language': 'http://d.opencalais.com/lid/DefaultLangId/English',
#   'permid': '505062'},
#  'http://d.opencalais.com/genericHasher-1/0d87e8a5-fb41-33c9-a1fb-bedf134b384e': {'_type': 'Position',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position',
#   'forenduserdisplay': 'false',
#   'instances': [{'detection': '[on his website read.\nJones also appealed to ]President[ Donald Trump for help on Monday, asking him to]',
#     'exact': 'President',
#     'length': 9,
#     'offset': 1855,
#     'prefix': 'on his website read.\nJones also appealed to ',
#     'suffix': ' Donald Trump for help on Monday, asking him to'}],
#   'name': 'President',
#   'relevance': 0.2},
#  'http://d.opencalais.com/genericHasher-1/3522a8be-1543-3661-9628-c8ef9999bb73': {'_type': 'CompanyAffiliates',
#   '_typeGroup': 'relations',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/CompanyAffiliates',
#   'affiliaterelationtype': 'owned',
#   'company_affiliate': 'http://d.opencalais.com/comphash-1/ab6c8681-759a-37ec-af62-b24109670f3d',
#   'company_parent': 'http://d.opencalais.com/comphash-1/22b46470-b64a-3af3-949a-b461fad44500',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[the content didn’t violate its guidelines.\n\n\n]Instagram, which is owned by Facebook[, did not immediately respond to a request for]',
#     'exact': 'Instagram, which is owned by Facebook',
#     'length': 37,
#     'offset': 1467,
#     'prefix': 'the content didn’t violate its guidelines.\n\n\n',
#     'suffix': ', did not immediately respond to a request for'}]},
#  'http://d.opencalais.com/genericHasher-1/365e1aea-c0f2-31e9-ac6b-47e09f545451': {'_type': 'Quotation',
#   '_typeGroup': 'relations',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/Quotation',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[of his movies are still available on Amazon. ]Twitter said the content didn’t violate its guidelines.[\n\n\nInstagram, which is owned by Facebook, did not]',
#     'exact': 'Twitter said the content didn’t violate its guidelines.',
#     'length': 55,
#     'offset': 1409,
#     'prefix': 'of his movies are still available on Amazon. ',
#     'suffix': '\n\n\nInstagram, which is owned by Facebook, did not'}],
#   'quotation': 'the content didn’t violate its guidelines',
#   'quotationtype': 'Paraphrase',
#   'speaker': 'http://d.opencalais.com/comphash-1/1076d1eb-4ea8-3d30-823a-db47764acc34'},
#  'http://d.opencalais.com/genericHasher-1/5d3d8131-9a80-3690-9179-80820eebd4ef': {'_type': 'IndustryTerm',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/IndustryTerm',
#   'forenduserdisplay': 'false',
#   'instances': [{'detection': '[election. And if you make the fact we need an ]Internet Bill[ of Rights, and antitrust-busting on these]',
#     'exact': 'Internet Bill',
#     'length': 13,
#     'offset': 2179,
#     'prefix': 'election. And if you make the fact we need an ',
#     'suffix': ' of Rights, and antitrust-busting on these'}],
#   'name': 'Internet Bill',
#   'relevance': 0.2},
#  'http://d.opencalais.com/genericHasher-1/71d696d3-4de7-3703-b91f-4e9b2d0e20c7': {'_type': 'Facility',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Facility',
#   'forenduserdisplay': 'false',
#   'instances': [{'detection': '[ active.\n\nListed under the “News” sections of the ]iOS App Store[ and the Google Play store, the Infowars app]',
#     'exact': 'iOS App Store',
#     'length': 13,
#     'offset': 262,
#     'prefix': ' active.\n\nListed under the “News” sections of the ',
#     'suffix': ' and the Google Play store, the Infowars app'}],
#   'name': 'iOS App Store',
#   'relevance': 0.2},
#  'http://d.opencalais.com/genericHasher-1/7ea05779-bca9-3ec8-bd8d-4fdd8522895b': {'_type': 'PersonCareer',
#   '_typeGroup': 'relations',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonCareer',
#   'careertype': 'professional',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[on his website read.\nJones also appealed to ]President Donald Trump[ for help on Monday, asking him to make a bigger]',
#     'exact': 'President Donald Trump',
#     'length': 22,
#     'offset': 1855,
#     'prefix': 'on his website read.\nJones also appealed to ',
#     'suffix': ' for help on Monday, asking him to make a bigger'}],
#   'person': 'http://d.opencalais.com/pershash-1/3cb6735d-ad40-304e-b561-6fae64c71c32',
#   'position': 'President',
#   'status': 'current'},
#  'http://d.opencalais.com/genericHasher-1/80ac236c-4b3b-383c-a5a0-3173b4f24116': {'_type': 'IndustryTerm',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/IndustryTerm',
#   'forenduserdisplay': 'false',
#   'instances': [{'detection': '[has responded to the shutdowns by slamming the ]social media platforms[ as “lying bullies.” \n\n\n\n“The war on your mind is]',
#     'exact': 'social media platforms',
#     'length': 22,
#     'offset': 1613,
#     'prefix': 'has responded to the shutdowns by slamming the ',
#     'suffix': ' as “lying bullies.” \n\n\n\n“The war on your mind is'}],
#   'name': 'social media platforms',
#   'relevance': 0.2},
#  'http://d.opencalais.com/genericHasher-1/b7b29405-4291-3163-944a-4631b2baa1b4': {'_type': 'Facility',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Facility',
#   'forenduserdisplay': 'false',
#   'instances': [{'detection': '[ the “News” sections of the iOS App Store and the ]Google Play store[, the Infowars app offers its subscribers]',
#     'exact': 'Google Play store',
#     'length': 17,
#     'offset': 284,
#     'prefix': ' the “News” sections of the iOS App Store and the ',
#     'suffix': ', the Infowars app offers its subscribers'}],
#   'name': 'Google Play store',
#   'relevance': 0.2},
#  'http://d.opencalais.com/genericHasher-1/c738b135-a090-3a95-b6c0-a05217cd4244': {'_type': 'CompanyAffiliates',
#   '_typeGroup': 'relations',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/CompanyAffiliates',
#   'affiliaterelationtype': 'owned',
#   'company_affiliate': 'http://d.opencalais.com/comphash-1/b054d269-db85-31cc-bd7e-f522a6809170',
#   'company_parent': 'http://d.opencalais.com/comphash-1/c7172a98-4c8a-31a9-bfd4-ce426c8db3c0',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[some of Jones’ podcasts from iTunes, while ]YouTube, which is owned by Google[, removed his channel. \n\n“Apple does not tolerate]',
#     'exact': 'YouTube, which is owned by Google',
#     'length': 33,
#     'offset': 515,
#     'prefix': 'some of Jones’ podcasts from iTunes, while ',
#     'suffix': ', removed his channel. \n\n“Apple does not tolerate'}]},
#  'http://d.opencalais.com/pershash-1/3cb6735d-ad40-304e-b561-6fae64c71c32': {'_type': 'Person',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'commonname': 'Donald Trump',
#   'confidence': {'aggregate': '0.999',
#    'dblookup': '0.95',
#    'resolution': '0.86196935',
#    'statisticalfeature': '0.999'},
#   'confidencelevel': '0.999',
#   'firstname': 'Donald',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[website read.\nJones also appealed to President ]Donald Trump[ for help on Monday, asking him to make a bigger]',
#     'exact': 'Donald Trump',
#     'length': 12,
#     'offset': 1865,
#     'prefix': 'website read.\nJones also appealed to President ',
#     'suffix': ' for help on Monday, asking him to make a bigger'}],
#   'lastname': 'Trump',
#   'name': 'Donald Trump',
#   'nationality': 'N/A',
#   'permid': 'https://permid.org/1-404011',
#   'persontype': 'N/A',
#   'relevance': 0.2,
#   'resolutions': [{'commonname': 'Donald Trump',
#     'name': 'Donald John Trump',
#     'officerid': ['1309208', '650373', '55206'],
#     'paid': '34413176227',
#     'personid': '55206',
#     'score': 0.86196935}]},
#  'http://d.opencalais.com/pershash-1/728c659a-9c2e-3e8d-8e6a-cbbfaeb493da': {'_type': 'Person',
#   '_typeGroup': 'entities',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'commonname': 'Alex Jones',
#   'confidence': {'aggregate': '0.998',
#    'dblookup': '0.95',
#    'resolution': '0.0',
#    'statisticalfeature': '0.984'},
#   'confidencelevel': '0.998',
#   'firstname': 'Alex',
#   'forenduserdisplay': 'true',
#   'instances': [{'detection': '[and Google have both removed some ]Alex Jones[ content from some of their platforms, but his]',
#     'exact': 'Alex Jones',
#     'length': 10,
#     'offset': 40,
#     'prefix': 'and Google have both removed some ',
#     'suffix': ' content from some of their platforms, but his'},
#    {'detection': '[Jones content from some of their platforms, but ]his[ Infowars app is still available for download in]',
#     'exact': 'his',
#     'length': 3,
#     'offset': 93,
#     'prefix': 'Jones content from some of their platforms, but ',
#     'suffix': ' Infowars app is still available for download in'},
#    {'detection': '[available for download in both app stores and ]his[ accounts on Twitter and Instagram are still]',
#     'exact': 'his',
#     'length': 3,
#     'offset': 165,
#     'prefix': 'available for download in both app stores and ',
#     'suffix': ' accounts on Twitter and Instagram are still'},
#    {'detection': '[to CNN Money.\n\nApple did remove some of ]Jones[’ podcasts from iTunes, while YouTube, which is]',
#     'exact': 'Jones',
#     'length': 5,
#     'offset': 480,
#     'prefix': 'to CNN Money.\n\nApple did remove some of ',
#     'suffix': '’ podcasts from iTunes, while YouTube, which is'},
#    {'detection': '[ while YouTube, which is owned by Google, removed ]his[ channel. \n\n“Apple does not tolerate hate speech,]',
#     'exact': 'his',
#     'length': 3,
#     'offset': 558,
#     'prefix': ' while YouTube, which is owned by Google, removed ',
#     'suffix': ' channel. \n\n“Apple does not tolerate hate speech,'},
#    {'detection': '[LinkedIn and Pinterest ― have removed some of ]Jones[’ content, saying it violated hate speech]',
#     'exact': 'Jones',
#     'length': 5,
#     'offset': 1186,
#     'prefix': 'LinkedIn and Pinterest ― have removed some of ',
#     'suffix': '’ content, saying it violated hate speech'},
#    {'detection': '[saying it violated hate speech policies. \n\nYet ]his[ accounts on Instagram, Twitter and Periscope]',
#     'exact': 'his',
#     'length': 3,
#     'offset': 1249,
#     'prefix': 'saying it violated hate speech policies. \n\nYet ',
#     'suffix': ' accounts on Instagram, Twitter and Periscope'},
#    {'detection': '[are still up and running, and several of ]his[ movies are still available on Amazon. Twitter]',
#     'exact': 'his',
#     'length': 3,
#     'offset': 1367,
#     'prefix': 'are still up and running, and several of ',
#     'suffix': ' movies are still available on Amazon. Twitter'},
#    {'detection': '[immediately respond to a request for comment.\n]Jones[ has responded to the shutdowns by slamming the]',
#     'exact': 'Jones',
#     'length': 5,
#     'offset': 1560,
#     'prefix': 'immediately respond to a request for comment.\n',
#     'suffix': ' has responded to the shutdowns by slamming the'},
#    {'detection': '[and truth, starting with the tip of the spear: ]Alex Jones[,” a statement on his website read.\nJones also]',
#     'exact': 'Alex Jones',
#     'length': 10,
#     'offset': 1786,
#     'prefix': 'and truth, starting with the tip of the spear: ',
#     'suffix': ',” a statement on his website read.\nJones also'},
#    {'detection': '[tip of the spear: Alex Jones,” a statement on ]his[ website read.\nJones also appealed to President]',
#     'exact': 'his',
#     'length': 3,
#     'offset': 1814,
#     'prefix': 'tip of the spear: Alex Jones,” a statement on ',
#     'suffix': ' website read.\nJones also appealed to President'},
#    {'detection': '[Alex Jones,” a statement on his website read.\n]Jones[ also appealed to President Donald Trump for help]',
#     'exact': 'Jones',
#     'length': 5,
#     'offset': 1832,
#     'prefix': 'Alex Jones,” a statement on his website read.\n',
#     'suffix': ' also appealed to President Donald Trump for help'},
#    {'detection': '[Donald Trump for help on Monday, asking ]him[ to make a bigger deal of the fact that the]',
#     'exact': 'him',
#     'length': 3,
#     'offset': 1905,
#     'prefix': 'Donald Trump for help on Monday, asking ',
#     'suffix': ' to make a bigger deal of the fact that the'},
#    {'detection': '[companies, if they don’t back off right now,” ]Jones[ said. \n]',
#     'exact': 'Jones',
#     'length': 5,
#     'offset': 2281,
#     'prefix': 'companies, if they don’t back off right now,” ',
#     'suffix': ' said. \n'}],
#   'lastname': 'Jones',
#   'name': 'Alex Jones',
#   'nationality': 'N/A',
#   'permid': 'https://permid.org/1-404011',
#   'persontype': 'N/A',
#   'relevance': 0.8}}

# %%
topics = list(c.keys())[1:]

# %%
for topic in topics:
    try:
        print(c[topic]['name'])
        if(c[topic]["_typeGroup"] in ['topics', 'socialTag']):
            print("importance:", c[topic]['importance'])
        else:
            print("relevance:", c[topic]['relevance'])
    except:
        pass
    print()
# Out:
# Technology_Internet
#
#
# Software
# importance: 1
#
# Computing
# importance: 1
#
# Digital media
# importance: 1
#
# Social media
# importance: 2
#
# Social networking services
# importance: 2
#
# Universal Windows Platform apps
# importance: 2
#
# Photo sharing
# importance: 2
#
# E-commerce
# importance: 2
#
# Instagram
# importance: 2
#
# InfoWars
# importance: 2
#
# Stitcher Radio
# importance: 2
#
# Facebook
# importance: 2
#
# Broadcasting - NEC
# relevance: 0
#
# Internet & Mail Order Department Stores
# relevance: 0
#
# Phones & Smart Phones
# relevance: 0.5
#
# Social Media & Networking
# relevance: 0.2
#
# Search Engines
# relevance: 0.2
#
# Software - NEC
# relevance: 0
#
# Internet Services - NEC
# relevance: 0.2
#
#
# Instagram
# relevance: 0
#
# Pinterest
# relevance: 0.2
#
# LinkedIn
# relevance: 0.2
#
# Amazon
# relevance: 0
#
# President
# relevance: 0.2
#
# iOS App Store
# relevance: 0.2
#
# SPOTIFY
# relevance: 0
#
# social media platforms
# relevance: 0.2
#
# Twitter
# relevance: 0
#
# Internet Bill
# relevance: 0.2
#
# Google
# relevance: 0.2
#
# YouTube
# relevance: 0.2
#
# Facebook
# relevance: 0.2
#
# Alex Jones
# relevance: 0.8
#
# Donald Trump
# relevance: 0.2
#
# CNN
# relevance: 0
#
# Google Play store
# relevance: 0.2
#
# Apple
# relevance: 0.5

# %%
for topic in topics:
    try:
        print(c[topic]['name'])
        print(c[topic])
        print("mentioned",len(c[topic]['instances']),"times")
        

    except:
        pass
    print()
# Out:
# Technology_Internet
# {'_typeGroup': 'topics', 'forenduserdisplay': 'false', 'score': 0.957, 'name': 'Technology_Internet'}
#
#
# Software
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/1', 'socialTag': 'http://d.opencalais.com/genericHasher-1/16293516-a848-3162-8f98-a310581b027d', 'forenduserdisplay': 'true', 'name': 'Software', 'importance': '1', 'originalValue': 'Software'}
#
# Computing
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/2', 'socialTag': 'http://d.opencalais.com/genericHasher-1/4f9a3d55-33f5-3738-a2f7-3e9065a5a169', 'forenduserdisplay': 'true', 'name': 'Computing', 'importance': '1', 'originalValue': 'Computing'}
#
# Digital media
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/3', 'socialTag': 'http://d.opencalais.com/genericHasher-1/771e4d9a-b0cd-37a2-bec6-6840c4cafab3', 'forenduserdisplay': 'true', 'name': 'Digital media', 'importance': '1', 'originalValue': 'Digital media'}
#
# Social media
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/4', 'socialTag': 'http://d.opencalais.com/genericHasher-1/26585b85-a498-31bb-abc9-70fdd3d7fb7c', 'forenduserdisplay': 'true', 'name': 'Social media', 'importance': '2', 'originalValue': 'Social media'}
#
# Social networking services
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/5', 'socialTag': 'http://d.opencalais.com/genericHasher-1/2021b3a9-eeac-3890-98ce-6367a7a57c7d', 'forenduserdisplay': 'true', 'name': 'Social networking services', 'importance': '2', 'originalValue': 'Social networking services'}
#
# Universal Windows Platform apps
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/6', 'socialTag': 'http://d.opencalais.com/genericHasher-1/03a060f0-38ee-3f7d-9a8b-ddd525e757f7', 'forenduserdisplay': 'true', 'name': 'Universal Windows Platform apps', 'importance': '2', 'originalValue': 'Universal Windows Platform apps'}
#
# Photo sharing
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/7', 'socialTag': 'http://d.opencalais.com/genericHasher-1/37265ce8-0e57-377a-b088-9ec4d1a5e30e', 'forenduserdisplay': 'true', 'name': 'Photo sharing', 'importance': '2', 'originalValue': 'Photo sharing'}
#
# E-commerce
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/8', 'socialTag': 'http://d.opencalais.com/genericHasher-1/55c4fa6b-02ac-3970-964f-ce38d6d583e4', 'forenduserdisplay': 'true', 'name': 'E-commerce', 'importance': '2', 'originalValue': 'E-commerce'}
#
# Instagram
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/9', 'socialTag': 'http://d.opencalais.com/genericHasher-1/ab63b26b-ec99-34a0-8f6a-1d7c1c54a6c9', 'forenduserdisplay': 'true', 'name': 'Instagram', 'importance': '2', 'originalValue': 'Instagram'}
#
# InfoWars
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/10', 'socialTag': 'http://d.opencalais.com/genericHasher-1/93a7d8a8-da53-30b0-8fe8-a3ca907ddcde', 'forenduserdisplay': 'true', 'name': 'InfoWars', 'importance': '2', 'originalValue': 'InfoWars'}
#
# Stitcher Radio
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/11', 'socialTag': 'http://d.opencalais.com/genericHasher-1/92cfc040-f5e6-3357-ade6-c4951d665c7c', 'forenduserdisplay': 'true', 'name': 'Stitcher Radio', 'importance': '2', 'originalValue': 'Stitcher Radio'}
#
# Facebook
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/002fcf23-1236-38e4-9fe2-1ec16bb33b4c/SocialTag/12', 'socialTag': 'http://d.opencalais.com/genericHasher-1/b4f3a1a1-a94a-380c-8fb6-7d61fd802b3d', 'forenduserdisplay': 'true', 'name': 'Facebook', 'importance': '2', 'originalValue': 'Facebook'}
#
# Broadcasting - NEC
# {'_typeGroup': 'industry', 'forenduserdisplay': 'false', 'name': 'Broadcasting - NEC', 'rcscode': 'B:1446', 'permid': '4294951555', 'relevance': 0}
#
# Internet & Mail Order Department Stores
# {'_typeGroup': 'industry', 'forenduserdisplay': 'false', 'name': 'Internet & Mail Order Department Stores', 'rcscode': 'B:1467', 'permid': '4294951534', 'relevance': 0}
#
# Phones & Smart Phones
# {'_typeGroup': 'industry', 'forenduserdisplay': 'false', 'name': 'Phones & Smart Phones', 'rcscode': 'B:1769', 'permid': '4294951232', 'relevance': 0.5}
#
# Social Media & Networking
# {'_typeGroup': 'industry', 'forenduserdisplay': 'false', 'name': 'Social Media & Networking', 'rcscode': 'B:1806', 'permid': '4294951195', 'relevance': 0.2}
#
# Search Engines
# {'_typeGroup': 'industry', 'forenduserdisplay': 'false', 'name': 'Search Engines', 'rcscode': 'B:1805', 'permid': '4294951196', 'relevance': 0.2}
#
# Software - NEC
# {'_typeGroup': 'industry', 'forenduserdisplay': 'false', 'name': 'Software - NEC', 'rcscode': 'B:1796', 'permid': '4294951205', 'relevance': 0}
#
# Internet Services - NEC
# {'_typeGroup': 'industry', 'forenduserdisplay': 'false', 'name': 'Internet Services - NEC', 'rcscode': 'B:1804', 'permid': '4294951197', 'relevance': 0.2}
#
#
# Instagram
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'false', 'name': 'Instagram', 'nationality': 'N/A', 'confidencelevel': '0.795', 'recognizedas': 'name', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[both app stores and his accounts on Twitter and ]Instagram[ are still active.\n\nListed under the “News”]', 'prefix': 'both app stores and his accounts on Twitter and ', 'exact': 'Instagram', 'suffix': ' are still active.\n\nListed under the “News”', 'offset': 193, 'length': 9}, {'detection': '[hate speech policies. \n\nYet his accounts on ]Instagram[, Twitter and Periscope (which is owned by]', 'prefix': 'hate speech policies. \n\nYet his accounts on ', 'exact': 'Instagram', 'suffix': ', Twitter and Periscope (which is owned by', 'offset': 1265, 'length': 9}, {'detection': '[the content didn’t violate its guidelines.\n\n\n]Instagram[, which is owned by Facebook, did not immediately]', 'prefix': 'the content didn’t violate its guidelines.\n\n\n', 'exact': 'Instagram', 'suffix': ', which is owned by Facebook, did not immediately', 'offset': 1467, 'length': 9}], 'relevance': 0, 'resolutions': [{'name': 'INSTAGRAM, INC.', 'permid': '5037430461', 'ispublic': 'false', 'commonname': 'Instagram', 'score': 0.17043427, 'id': 'https://permid.org/1-5037430461'}], 'confidence': {'statisticalfeature': '0.922', 'dblookup': '0.0', 'resolution': '0.17043427', 'aggregate': '0.795'}}
# mentioned 3 times
#
# Pinterest
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'true', 'name': 'Pinterest', 'nationality': 'N/A', 'confidencelevel': '1.0', 'recognizedas': 'name', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[Stitcher and, most recently, LinkedIn and ]Pinterest[ ― have removed some of Jones’ content, saying it]', 'prefix': 'Stitcher and, most recently, LinkedIn and ', 'exact': 'Pinterest', 'suffix': ' ― have removed some of Jones’ content, saying it', 'offset': 1153, 'length': 9}], 'relevance': 0.2, 'confidence': {'statisticalfeature': '0.916', 'dblookup': '0.0', 'resolution': '0.07729884', 'aggregate': '1.0'}, 'resolutions': [{'name': 'COLD BREAW LABS INC.', 'permid': '5036190505', 'ispublic': 'false', 'commonname': 'Pinterest', 'score': 0.07729884, 'id': 'https://permid.org/1-5036190505'}]}
# mentioned 1 times
#
# LinkedIn
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'true', 'name': 'LinkedIn', 'nationality': 'N/A', 'confidencelevel': '1.0', 'recognizedas': 'name', 'resolutions': [{'name': 'LINKEDIN CORPORATION', 'permid': '4296977663', 'ispublic': 'false', 'commonname': 'LnkIn Corp', 'score': 0.67992806, 'id': 'https://permid.org/1-4296977663', 'ticker': 'LNKD'}], '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[Spotify, Facebook, Stitcher and, most recently, ]LinkedIn[ and Pinterest ― have removed some of Jones’]', 'prefix': 'Spotify, Facebook, Stitcher and, most recently, ', 'exact': 'LinkedIn', 'suffix': ' and Pinterest ― have removed some of Jones’', 'offset': 1140, 'length': 8}], 'relevance': 0.2, 'confidence': {'statisticalfeature': '0.905', 'dblookup': '0.0', 'resolution': '0.67992806', 'aggregate': '1.0'}}
# mentioned 1 times
#
# Amazon
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'true', 'name': 'Amazon', 'nationality': 'N/A', 'confidencelevel': '0.993', 'recognizedas': 'name', 'confidence': {'statisticalfeature': '0.905', 'dblookup': '0.0', 'resolution': '0.99360967', 'aggregate': '0.993'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[ and several of his movies are still available on ]Amazon[. Twitter said the content didn’t violate its]', 'prefix': ' and several of his movies are still available on ', 'exact': 'Amazon', 'suffix': '. Twitter said the content didn’t violate its', 'offset': 1401, 'length': 6}], 'relevance': 0, 'resolutions': [{'name': 'AMAZON.COM, INC.', 'permid': '4295905494', 'primaryric': 'AMZN.OQ', 'ispublic': 'true', 'commonname': 'Amazon.com', 'score': 0.99360967, 'id': 'https://permid.org/1-4295905494', 'ticker': 'AMZN'}]}
# mentioned 1 times
#
# President
# {'_typeGroup': 'entities', '_type': 'Position', 'forenduserdisplay': 'false', 'name': 'President', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position', 'instances': [{'detection': '[on his website read.\nJones also appealed to ]President[ Donald Trump for help on Monday, asking him to]', 'prefix': 'on his website read.\nJones also appealed to ', 'exact': 'President', 'suffix': ' Donald Trump for help on Monday, asking him to', 'offset': 1855, 'length': 9}], 'relevance': 0.2}
# mentioned 1 times
#
# iOS App Store
# {'_typeGroup': 'entities', '_type': 'Facility', 'forenduserdisplay': 'false', 'name': 'iOS App Store', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Facility', 'instances': [{'detection': '[ active.\n\nListed under the “News” sections of the ]iOS App Store[ and the Google Play store, the Infowars app]', 'prefix': ' active.\n\nListed under the “News” sections of the ', 'exact': 'iOS App Store', 'suffix': ' and the Google Play store, the Infowars app', 'offset': 262, 'length': 13}], 'relevance': 0.2}
# mentioned 1 times
#
# SPOTIFY
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'true', 'name': 'SPOTIFY', 'confidencelevel': '1.0', 'recognizedas': 'name', 'resolutions': [{'name': 'SPOTIFY TECHNOLOGY S.A.', 'permid': '5037833896', 'primaryric': 'SPOT.N', 'ispublic': 'true', 'commonname': 'Spotify Tech', 'score': 1, 'id': 'https://permid.org/1-5037833896', 'ticker': 'SPOT'}], '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[ growing list of other tech companies ― including ]Spotify[, Facebook, Stitcher and, most recently, LinkedIn]', 'prefix': ' growing list of other tech companies ― including ', 'exact': 'Spotify', 'suffix': ', Facebook, Stitcher and, most recently, LinkedIn', 'offset': 1092, 'length': 7}], 'relevance': 0, 'confidence': {'statisticalfeature': '0.644', 'dblookup': '0.0', 'resolution': '1.0', 'aggregate': '1.0'}}
# mentioned 1 times
#
# social media platforms
# {'_typeGroup': 'entities', '_type': 'IndustryTerm', 'forenduserdisplay': 'false', 'name': 'social media platforms', '_typeReference': 'http://s.opencalais.com/1/type/em/e/IndustryTerm', 'instances': [{'detection': '[has responded to the shutdowns by slamming the ]social media platforms[ as “lying bullies.” \n\n\n\n“The war on your mind is]', 'prefix': 'has responded to the shutdowns by slamming the ', 'exact': 'social media platforms', 'suffix': ' as “lying bullies.” \n\n\n\n“The war on your mind is', 'offset': 1613, 'length': 22}], 'relevance': 0.2}
# mentioned 1 times
#
# Twitter
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'true', 'name': 'Twitter', 'nationality': 'N/A', 'confidencelevel': '0.966', 'recognizedas': 'name', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[download in both app stores and his accounts on ]Twitter[ and Instagram are still active.\n\nListed under]', 'prefix': 'download in both app stores and his accounts on ', 'exact': 'Twitter', 'suffix': ' and Instagram are still active.\n\nListed under', 'offset': 181, 'length': 7}, {'detection': '[policies. \n\nYet his accounts on Instagram, ]Twitter[ and Periscope (which is owned by Twitter) are]', 'prefix': 'policies. \n\nYet his accounts on Instagram, ', 'exact': 'Twitter', 'suffix': ' and Periscope (which is owned by Twitter) are', 'offset': 1276, 'length': 7}, {'detection': '[Twitter and Periscope (which is owned by ]Twitter[) are still up and running, and several of his]', 'prefix': 'Twitter and Periscope (which is owned by ', 'exact': 'Twitter', 'suffix': ') are still up and running, and several of his', 'offset': 1317, 'length': 7}, {'detection': '[of his movies are still available on Amazon. ]Twitter[ said the content didn’t violate its]', 'prefix': 'of his movies are still available on Amazon. ', 'exact': 'Twitter', 'suffix': ' said the content didn’t violate its', 'offset': 1409, 'length': 7}], 'relevance': 0, 'confidence': {'statisticalfeature': '0.956', 'dblookup': '0.0', 'resolution': '0.9876603', 'aggregate': '0.966'}, 'resolutions': [{'name': 'TWITTER, INC.', 'permid': '4296301199', 'primaryric': 'TWTR.N', 'ispublic': 'true', 'commonname': 'Twitter', 'score': 0.9876603, 'id': 'https://permid.org/1-4296301199', 'ticker': 'TWTR'}]}
# mentioned 4 times
#
# Internet Bill
# {'_typeGroup': 'entities', '_type': 'IndustryTerm', 'forenduserdisplay': 'false', 'name': 'Internet Bill', '_typeReference': 'http://s.opencalais.com/1/type/em/e/IndustryTerm', 'instances': [{'detection': '[election. And if you make the fact we need an ]Internet Bill[ of Rights, and antitrust-busting on these]', 'prefix': 'election. And if you make the fact we need an ', 'exact': 'Internet Bill', 'suffix': ' of Rights, and antitrust-busting on these', 'offset': 2179, 'length': 13}], 'relevance': 0.2}
# mentioned 1 times
#
# Google
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'true', 'name': 'Google', 'confidencelevel': '0.999', 'recognizedas': 'name', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[Apple and ]Google[ have both removed some Alex Jones content from]', 'prefix': 'Apple and ', 'exact': 'Google', 'suffix': ' have both removed some Alex Jones content from', 'offset': 10, 'length': 6}, {'detection': '[from iTunes, while YouTube, which is owned by ]Google[, removed his channel. \n\n“Apple does not tolerate]', 'prefix': 'from iTunes, while YouTube, which is owned by ', 'exact': 'Google', 'suffix': ', removed his channel. \n\n“Apple does not tolerate', 'offset': 542, 'length': 6}], 'relevance': 0.2, 'confidence': {'statisticalfeature': '0.71', 'dblookup': '0.0', 'resolution': '1.0', 'aggregate': '0.999'}, 'resolutions': [{'name': 'GOOGLE LLC', 'permid': '4295899948', 'ispublic': 'false', 'commonname': 'Google', 'score': 1, 'id': 'https://permid.org/1-4295899948'}]}
# mentioned 2 times
#
# YouTube
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'true', 'name': 'YouTube', 'nationality': 'N/A', 'confidencelevel': '0.994', 'recognizedas': 'name', 'confidence': {'statisticalfeature': '0.905', 'dblookup': '0.0', 'resolution': '0.18957536', 'aggregate': '0.994'}, 'resolutions': [{'name': 'YouTube, LLC', 'permid': '4297403627', 'ispublic': 'false', 'commonname': 'YouTube, LLC', 'score': 0.18957536, 'id': 'https://permid.org/1-4297403627'}], '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[some of Jones’ podcasts from iTunes, while ]YouTube[, which is owned by Google, removed his channel.]', 'prefix': 'some of Jones’ podcasts from iTunes, while ', 'exact': 'YouTube', 'suffix': ', which is owned by Google, removed his channel.', 'offset': 515, 'length': 7}], 'relevance': 0.2}
# mentioned 1 times
#
# Facebook
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'true', 'name': 'Facebook', 'nationality': 'N/A', 'confidencelevel': '0.995', 'recognizedas': 'name', 'confidence': {'statisticalfeature': '0.933', 'dblookup': '0.0', 'resolution': '0.9931863', 'aggregate': '0.995'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[of other tech companies ― including Spotify, ]Facebook[, Stitcher and, most recently, LinkedIn and]', 'prefix': 'of other tech companies ― including Spotify, ', 'exact': 'Facebook', 'suffix': ', Stitcher and, most recently, LinkedIn and', 'offset': 1101, 'length': 8}, {'detection': '[its guidelines.\n\n\nInstagram, which is owned by ]Facebook[, did not immediately respond to a request for]', 'prefix': 'its guidelines.\n\n\nInstagram, which is owned by ', 'exact': 'Facebook', 'suffix': ', did not immediately respond to a request for', 'offset': 1496, 'length': 8}], 'relevance': 0.2, 'resolutions': [{'name': 'FACEBOOK, INC.', 'permid': '4297297477', 'primaryric': 'FB.OQ', 'ispublic': 'true', 'commonname': 'Facebook', 'score': 0.9931863, 'id': 'https://permid.org/1-4297297477', 'ticker': 'FB'}]}
# mentioned 2 times
#
# Alex Jones
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Alex Jones', 'persontype': 'N/A', 'nationality': 'N/A', 'confidencelevel': '0.998', 'firstname': 'Alex', 'lastname': 'Jones', 'commonname': 'Alex Jones', 'confidence': {'statisticalfeature': '0.984', 'dblookup': '0.95', 'resolution': '0.0', 'aggregate': '0.998'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[and Google have both removed some ]Alex Jones[ content from some of their platforms, but his]', 'prefix': 'and Google have both removed some ', 'exact': 'Alex Jones', 'suffix': ' content from some of their platforms, but his', 'offset': 40, 'length': 10}, {'detection': '[Jones content from some of their platforms, but ]his[ Infowars app is still available for download in]', 'prefix': 'Jones content from some of their platforms, but ', 'exact': 'his', 'suffix': ' Infowars app is still available for download in', 'offset': 93, 'length': 3}, {'detection': '[available for download in both app stores and ]his[ accounts on Twitter and Instagram are still]', 'prefix': 'available for download in both app stores and ', 'exact': 'his', 'suffix': ' accounts on Twitter and Instagram are still', 'offset': 165, 'length': 3}, {'detection': '[to CNN Money.\n\nApple did remove some of ]Jones[’ podcasts from iTunes, while YouTube, which is]', 'prefix': 'to CNN Money.\n\nApple did remove some of ', 'exact': 'Jones', 'suffix': '’ podcasts from iTunes, while YouTube, which is', 'offset': 480, 'length': 5}, {'detection': '[ while YouTube, which is owned by Google, removed ]his[ channel. \n\n“Apple does not tolerate hate speech,]', 'prefix': ' while YouTube, which is owned by Google, removed ', 'exact': 'his', 'suffix': ' channel. \n\n“Apple does not tolerate hate speech,', 'offset': 558, 'length': 3}, {'detection': '[LinkedIn and Pinterest ― have removed some of ]Jones[’ content, saying it violated hate speech]', 'prefix': 'LinkedIn and Pinterest ― have removed some of ', 'exact': 'Jones', 'suffix': '’ content, saying it violated hate speech', 'offset': 1186, 'length': 5}, {'detection': '[saying it violated hate speech policies. \n\nYet ]his[ accounts on Instagram, Twitter and Periscope]', 'prefix': 'saying it violated hate speech policies. \n\nYet ', 'exact': 'his', 'suffix': ' accounts on Instagram, Twitter and Periscope', 'offset': 1249, 'length': 3}, {'detection': '[are still up and running, and several of ]his[ movies are still available on Amazon. Twitter]', 'prefix': 'are still up and running, and several of ', 'exact': 'his', 'suffix': ' movies are still available on Amazon. Twitter', 'offset': 1367, 'length': 3}, {'detection': '[immediately respond to a request for comment.\n]Jones[ has responded to the shutdowns by slamming the]', 'prefix': 'immediately respond to a request for comment.\n', 'exact': 'Jones', 'suffix': ' has responded to the shutdowns by slamming the', 'offset': 1560, 'length': 5}, {'detection': '[and truth, starting with the tip of the spear: ]Alex Jones[,” a statement on his website read.\nJones also]', 'prefix': 'and truth, starting with the tip of the spear: ', 'exact': 'Alex Jones', 'suffix': ',” a statement on his website read.\nJones also', 'offset': 1786, 'length': 10}, {'detection': '[tip of the spear: Alex Jones,” a statement on ]his[ website read.\nJones also appealed to President]', 'prefix': 'tip of the spear: Alex Jones,” a statement on ', 'exact': 'his', 'suffix': ' website read.\nJones also appealed to President', 'offset': 1814, 'length': 3}, {'detection': '[Alex Jones,” a statement on his website read.\n]Jones[ also appealed to President Donald Trump for help]', 'prefix': 'Alex Jones,” a statement on his website read.\n', 'exact': 'Jones', 'suffix': ' also appealed to President Donald Trump for help', 'offset': 1832, 'length': 5}, {'detection': '[Donald Trump for help on Monday, asking ]him[ to make a bigger deal of the fact that t ...
# mentioned 14 times
#
# Donald Trump
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Donald Trump', 'persontype': 'N/A', 'nationality': 'N/A', 'confidencelevel': '0.999', 'firstname': 'Donald', 'lastname': 'Trump', 'commonname': 'Donald Trump', 'resolutions': [{'name': 'Donald John Trump', 'personid': '55206', 'paid': '34413176227', 'officerid': ['1309208', '650373', '55206'], 'commonname': 'Donald Trump', 'score': 0.86196935}], 'confidence': {'statisticalfeature': '0.999', 'dblookup': '0.95', 'resolution': '0.86196935', 'aggregate': '0.999'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[website read.\nJones also appealed to President ]Donald Trump[ for help on Monday, asking him to make a bigger]', 'prefix': 'website read.\nJones also appealed to President ', 'exact': 'Donald Trump', 'suffix': ' for help on Monday, asking him to make a bigger', 'offset': 1865, 'length': 12}], 'relevance': 0.2}
# mentioned 1 times
#
# CNN
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'false', 'name': 'CNN', 'nationality': 'N/A', 'confidencelevel': '0.89', 'recognizedas': 'name', 'resolutions': [{'name': 'CABLE NEWS NETWORK, INC.', 'permid': '4298210469', 'ispublic': 'false', 'commonname': 'CNN', 'score': 1, 'id': 'https://permid.org/1-4298210469'}], 'confidence': {'statisticalfeature': '0.799', 'dblookup': '0.0', 'resolution': '1.0', 'aggregate': '0.89'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[23 among free news apps on Apple, according to ]CNN[ Money.\n\nApple did remove some of Jones’ podcasts]', 'prefix': '23 among free news apps on Apple, according to ', 'exact': 'CNN', 'suffix': ' Money.\n\nApple did remove some of Jones’ podcasts', 'offset': 443, 'length': 3}], 'relevance': 0}
# mentioned 1 times
#
# Google Play store
# {'_typeGroup': 'entities', '_type': 'Facility', 'forenduserdisplay': 'false', 'name': 'Google Play store', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Facility', 'instances': [{'detection': '[ the “News” sections of the iOS App Store and the ]Google Play store[, the Infowars app offers its subscribers]', 'prefix': ' the “News” sections of the iOS App Store and the ', 'exact': 'Google Play store', 'suffix': ', the Infowars app offers its subscribers', 'offset': 284, 'length': 17}], 'relevance': 0.2}
# mentioned 1 times
#
# Apple
# {'_typeGroup': 'entities', '_type': 'Company', 'forenduserdisplay': 'true', 'name': 'Apple', 'nationality': 'N/A', 'confidencelevel': '1.0', 'recognizedas': 'name', 'resolutions': [{'name': 'APPLE INC.', 'permid': '4295905573', 'primaryric': 'AAPL.OQ', 'ispublic': 'true', 'commonname': 'Apple', 'score': 0.9945767, 'id': 'https://permid.org/1-4295905573', 'ticker': 'AAPL'}], 'confidence': {'statisticalfeature': '0.956', 'dblookup': '0.0', 'resolution': '0.9945767', 'aggregate': '1.0'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company', 'instances': [{'detection': '[]Apple[ and Google have both removed some Alex Jones]', 'exact': 'Apple', 'suffix': ' and Google have both removed some Alex Jones', 'offset': 0, 'length': 5}, {'detection': '[ ranked as high as No. 23 among free news apps on ]Apple[, according to CNN Money.\n\nApple did remove some]', 'prefix': ' ranked as high as No. 23 among free news apps on ', 'exact': 'Apple', 'suffix': ', according to CNN Money.\n\nApple did remove some', 'offset': 423, 'length': 5}, {'detection': '[news apps on Apple, according to CNN Money.\n\n]Apple[ did remove some of Jones’ podcasts from iTunes,]', 'prefix': 'news apps on Apple, according to CNN Money.\n\n', 'exact': 'Apple', 'suffix': ' did remove some of Jones’ podcasts from iTunes,', 'offset': 455, 'length': 5}, {'detection': '[is owned by Google, removed his channel. \n\n“]Apple[ does not tolerate hate speech, and we have clear]', 'prefix': 'is owned by Google, removed his channel. \n\n“', 'exact': 'Apple', 'suffix': ' does not tolerate hate speech, and we have clear', 'offset': 574, 'length': 5}], 'relevance': 0.5}
# mentioned 4 times

# %% [markdown]
# At this point, the next step is to synthesize these results into a search querry
