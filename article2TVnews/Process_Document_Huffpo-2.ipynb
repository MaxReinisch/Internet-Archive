# %% [markdown]
# # This Project's aim is to recommend a tv-news clip based on a given article using a content filter recommender

# %% [markdown]
# # Summary of the project:
#
# #### Static structure
# To build this, we will need a DB of the possible recommendations. This will have features such as:
# - `Title`
#     - Used to display to user
# - `entities`
#     - A vector of the features for each video
# - `url`
#     - A link to the full segment
#
#
# #### Program
# 1. We will programatically scan an article and parse it for its own entity vector.
#     - NLP topic modeling needed
# 2. Then we will find cosine dist from the article to each news clip.
# 3. return the 3 closest clips.
#
# #### Notes:
# - Depending on the size of the DB, we probably won't want to go through each entry.  Maybe I can cluster closer clips and return the cluster
# - Probably want to use components as well.
# - News sources: BBC, CNN, Fox, RT, MSNBC, Huffpo, the guardian,
# - opencalais
# -

# %% [markdown]
# ## Imports

# %%
from sklearn.feature_extraction.text import CountVectorizer
import requests
from bs4 import BeautifulSoup

# %%
access_token = "cvTFhY53VXBYm5HO85weHPx346W05015"
calais_url = 'https://api.thomsonreuters.com/permid/calais'
headers = {'X-AG-Access-Token' : access_token, 'Content-Type' : 'text/raw', 'outputformat' : 'application/json'}

# %% [markdown]
# ## Scan article
# - request site
#     - found this api:https://newsapi.org/
#         - Can't search individual articles by url as far as I can tell.  Might be worth considering though for multiple news sources
#         - Doesn't return full article, only title and desc
# - find relevant info
#     - http://mallet.cs.umass.edu/index.php
#     - http://www.opencalais.com/
# - assemble corpus OR run search on archive.org

# %% [markdown]
# #### Requests

# %%
url = 'https://www.huffingtonpost.com/entry/kansas-democrat-brent-welder-ad_us_5b625d65e4b0b15aba9f9774'
header = {"Accept-Encoding": "gzip", "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
res = requests.get(url, headers=header )
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %% [markdown]
# #### Parse

# %%
title = soup.find("h1", attrs={"class":"headline__title"}).text
title
# Out:
# 'New Ad For Democratic Candidate Tests A Populist Message In Suburban Kansas'

# %%
subtitle = soup.find("div", attrs={"class":"headline__subtitle"}).text
subtitle
# Out:
# 'Brent Welder is a progressive labor attorney running in Kansas’ 3rd Congressional District.'

# %%
soup.find("a", attrs={"class": "author-card__link yr-author-name"}).text
# Out:
# 'Daniel Marans'

# %%
body = "\n\n".join(list(map(lambda x: x.text, soup.find("div", attrs={"class":"entry__text"}).find_all("div", attrs={"class":"content-list-component"}))))
print(body)
# Out:
# The Progressive Change Campaign Committee is funding an advertisement in support of Brent Welder, a progressive lawyer seeking the Democratic nomination in Kansas’ 3rd Congressional District.
#
# The minute-long video, which consists almost entirely of a passionate segment from one of Welder’s speeches, banks on voters’ appetites for unabashed economic populism. Through its super PAC, the PCCC has purchased $30,000 worth of airtime to play the spot on the local morning and evening news in the Kansas City media market, starting Thursday.
#
# “The wealthiest of the wealthy take a tiny sliver of those enormous profits that they steal from us and use it to pay off politicians to keep it rigged in their favor,” Welder tells supporters at a July 20 rally featured in the video. “We gather here tonight to say, ‘Enough is enough!’”
#
#
#
# Welder, a union-side labor attorney and former campaign official for both Barack Obama and Sen. Bernie Sanders (I-Vt.), is in a close contest for the Democratic nomination in a district that includes Kansas City and many of its most affluent suburbs. The primary is next Tuesday.
#
# Welder delivered the speech on which the ad is based at a massive campaign rally in Kansas City where Sanders and Alexandria Ocasio-Cortez, the Democratic nominee in New York’s 14th Congressional District, spoke in support of his candidacy.
#
# Although there are six Democratic candidates, poll watchers believe the primary is effectively a three-way race. Welder’s top competitors are Tom Niermann, a centrist, private-school history teacher, and Sharice Davids, an EMILY’S List-backed attorney. Davids is more liberal than Niermann, but unlike Welder, is not running on Medicare for all and some other progressive priorities. (Davids told The Intercept that she would vote for a Medicare-for-all bill if it came up for a vote, but that she is focusing on interim steps given how difficult it will be to achieve in the near term.) She is running heavily on her personal story as a Native American lesbian and amateur MMA fighter, raised by a single Army veteran mom.
#
# The Democrats are vying for the chance to unseat Rep. Kevin Yoder (R-Kan.), who is considered one of the most vulnerable Republicans in Congress. Hillary Clinton defeated Donald Trump among the district’s voters by 1 percentage point; national Democrats put Trump’s approval rating there at about 35 percent.
#
# The suburb-heavy district is not necessarily fertile ground for a Sanders-style, class war battle cry. Local Democratic officials, who are mostly backing Niermann, see moderation as the surest ticket to a general-election win.
#
# But national progressives stumping for Welder can’t pass up the opportunity to show that left-wing populism is a political winner across the country ― even in a well-to-do swing seat in deep-red Kansas.
#
# Following Sanders and Ocasio-Cortez’s rally for Welder in the district, the PCCC’s ad attempts to give Welder still more populist momentum.
#
# And while Welder, like Ocasio-Cortez, is an alumnus of Sanders’ 2016 presidential run, the PCCC most closely associates itself with that other progressive tribune: Sen. Elizabeth Warren (D-Mass.).
#
# “Brent Welder is the type of Elizabeth Warren-style, bold progressive that excites voters in red, purple, and blue districts,” PCCC co-founder Adam Green said of the group’s ad. “His message of challenging corporate power over our political system and bold ideas like Medicare For All is exactly what will maximize a Democratic wave in 2018.”
#
# CORRECTION: A previous version of this story incorrectly referred to Sharice Davids as an Army veteran. Her mother served in the Army. It also incorrectly claimed that Davids does not support Medicare for all. She has said she would vote for it if it came up.

# %% [markdown]
# ## SKLearn NLP

# %% [markdown]
# ## Calais section

# %%
response = requests.post(calais_url, data=body.encode('utf-8'), headers=headers, timeout=80)
print ('status code: %s' % response.status_code)
content = response.text
# print ('Results received: %s' % content)
# Out:
# status code: 200

# %%
import json

c = json.loads(content)


topics = list(c.keys())[1:]

# %%
for topic in topics:
    try:
        print(c[topic]['name'])
        if(c[topic]["_typeGroup"] in ['topics', 'socialTag']):
            print("importance:", c[topic]['importance'])
        else:
            print("relevance:", c[topic]['relevance'])
    except:
        pass
    print()
# Out:
# Politics
#
#
# Politics of the United States
# importance: 1
#
# United States
# importance: 1
#
# Brent Welder
# importance: 1
#
# Bernie Sanders presidential campaign
# importance: 2
#
# Progressive Change Campaign Committee
# importance: 2
#
# Alexandria Ocasio-Cortez
# importance: 2
#
# Bernie Sanders
# importance: 2
#
# Democratic Party
# importance: 2
#
# Bio Therapeutic Drugs
# relevance: 0
#
#
# Kansas City
# relevance: 0.2
#
# Kevin Yoder
# relevance: 0.2
#
# Congress
# relevance: 0.2
#
# Kansas
# relevance: 0.8
#
# Progressive Change Campaign Committee
# relevance: 0.8
#
# official
# relevance: 0.2
#
# Alexandria Ocasio-Cortez
# relevance: 0.2
#
# Brent Welder
# relevance: 0.8
#
# Bernie Sanders
# relevance: 0.2
#
# co-founder
# relevance: 0.2
#
# Welder , a progressive lawyer
# relevance: 0.2
#
# media market
# relevance: 0.2
#
# Elizabeth Warren
# relevance: 0.2
#
# Welder , a union-side labor attorney
# relevance: 0.2
#
# Welder
# relevance: 0.8
#
# The primary
# relevance: 0.2
#
# Tom Niermann
# relevance: 0.2
#
# MMA
# relevance: 0.2
#
# Sharice Davids
# relevance: 0.2
#
# Adam Green
# relevance: 0.2
#
# Hillary Clinton
# relevance: 0.2
#
# Elizabeth Warren-style
# relevance: 0.2
#
# Barack Obama
# relevance: 0.2
#
# centrist, private-school history teacher
# relevance: 0.2
#
# List-backed attorney
# relevance: 0.2
#
# Army
# relevance: 0.2
#
# New York
# relevance: 0.2
#
# Massachusetts
# relevance: 0.2
#
# Donald Trump
# relevance: 0.2
#
# Medicare
# relevance: 0.2

# %%
for topic in topics:
    try:
        print(c[topic]['name'])
        print(c[topic])
        print("mentioned",len(c[topic]['instances']),"times")
        

    except:
        pass
    print()
# Out:
# Politics
# {'_typeGroup': 'topics', 'forenduserdisplay': 'false', 'score': 0.975, 'name': 'Politics'}
#
#
# Politics of the United States
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/f164e4d2-3f69-3e4b-b26d-9a42e3a6314f/SocialTag/1', 'socialTag': 'http://d.opencalais.com/genericHasher-1/450a0fe4-479f-343b-8ca1-2ced72c6b3ef', 'forenduserdisplay': 'true', 'name': 'Politics of the United States', 'importance': '1', 'originalValue': 'Politics of the United States'}
#
# United States
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/f164e4d2-3f69-3e4b-b26d-9a42e3a6314f/SocialTag/2', 'socialTag': 'http://d.opencalais.com/genericHasher-1/359e9bfd-d04d-3ee5-931a-c69b04eac8d2', 'forenduserdisplay': 'true', 'name': 'United States', 'importance': '1', 'originalValue': 'United States'}
#
# Brent Welder
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/f164e4d2-3f69-3e4b-b26d-9a42e3a6314f/SocialTag/3', 'socialTag': 'http://d.opencalais.com/genericHasher-1/ca3bd228-fa28-318a-bb0c-0480504f8a5a', 'forenduserdisplay': 'true', 'name': 'Brent Welder', 'importance': '1', 'originalValue': 'Brent Welder'}
#
# Bernie Sanders presidential campaign
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/f164e4d2-3f69-3e4b-b26d-9a42e3a6314f/SocialTag/4', 'socialTag': 'http://d.opencalais.com/genericHasher-1/34444130-bad0-37fa-b2dc-6d0169eaf1f0', 'forenduserdisplay': 'true', 'name': 'Bernie Sanders presidential campaign', 'importance': '2', 'originalValue': 'Bernie Sanders presidential campaign, 2016'}
#
# Progressive Change Campaign Committee
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/f164e4d2-3f69-3e4b-b26d-9a42e3a6314f/SocialTag/5', 'socialTag': 'http://d.opencalais.com/genericHasher-1/3172a5cd-bbba-3de7-ab0c-0a3f6e9214a0', 'forenduserdisplay': 'true', 'name': 'Progressive Change Campaign Committee', 'importance': '2', 'originalValue': 'Progressive Change Campaign Committee'}
#
# Alexandria Ocasio-Cortez
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/f164e4d2-3f69-3e4b-b26d-9a42e3a6314f/SocialTag/6', 'socialTag': 'http://d.opencalais.com/genericHasher-1/7706dcdf-640d-39c4-976b-6b656f3fc34f', 'forenduserdisplay': 'true', 'name': 'Alexandria Ocasio-Cortez', 'importance': '2', 'originalValue': 'Alexandria Ocasio-Cortez'}
#
# Bernie Sanders
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/f164e4d2-3f69-3e4b-b26d-9a42e3a6314f/SocialTag/7', 'socialTag': 'http://d.opencalais.com/genericHasher-1/48119479-07ab-3663-920b-e21cfa03ff5c', 'forenduserdisplay': 'true', 'name': 'Bernie Sanders', 'importance': '2', 'originalValue': 'Bernie Sanders'}
#
# Democratic Party
# {'_typeGroup': 'socialTag', 'id': 'http://d.opencalais.com/dochash-1/f164e4d2-3f69-3e4b-b26d-9a42e3a6314f/SocialTag/8', 'socialTag': 'http://d.opencalais.com/genericHasher-1/c1bcf03d-a054-3fa0-b622-75311bdd1bea', 'forenduserdisplay': 'true', 'name': 'Democratic Party', 'importance': '2', 'originalValue': 'Democratic Party (United States)'}
#
# Bio Therapeutic Drugs
# {'_typeGroup': 'industry', 'forenduserdisplay': 'false', 'name': 'Bio Therapeutic Drugs', 'rcscode': 'B:1737', 'permid': '4294951264', 'relevance': 0}
#
#
# Kansas City
# {'_typeGroup': 'entities', '_type': 'City', 'forenduserdisplay': 'true', 'name': 'Kansas City', '_typeReference': 'http://s.opencalais.com/1/type/em/e/City', 'instances': [{'detection': '[on the local morning and evening news in the ]Kansas City[ media market, starting Thursday.\n\n“The]', 'prefix': 'on the local morning and evening news in the ', 'exact': 'Kansas City', 'suffix': ' media market, starting Thursday.\n\n“The', 'offset': 495, 'length': 11}, {'detection': '[nomination in a district that includes ]Kansas City[ and many of its most affluent suburbs. The]', 'prefix': 'nomination in a district that includes ', 'exact': 'Kansas City', 'suffix': ' and many of its most affluent suburbs. The', 'offset': 1032, 'length': 11}, {'detection': '[the ad is based at a massive campaign rally in ]Kansas City[ where Sanders and Alexandria Ocasio-Cortez, the]', 'prefix': 'the ad is based at a massive campaign rally in ', 'exact': 'Kansas City', 'suffix': ' where Sanders and Alexandria Ocasio-Cortez, the', 'offset': 1197, 'length': 11}], 'relevance': 0.2, 'resolutions': [{'name': 'Kansas City,Oregon,United States', 'shortname': 'Kansas City', 'latitude': '45.5959464', 'longitude': '-123.147054', 'containedbystate': 'Oregon', 'containedbycountry': 'United States', 'rcscode': 'G:1ET'}]}
# mentioned 3 times
#
# Kevin Yoder
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Kevin Yoder', 'persontype': 'political', 'nationality': 'N/A', 'confidencelevel': '0.995', 'firstname': 'Kevin', 'lastname': 'Yoder', 'commonname': 'Kevin Yoder', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[Democrats are vying for the chance to unseat ]Rep. Kevin Yoder[ (R-Kan.), who is considered one of the most]', 'prefix': 'Democrats are vying for the chance to unseat ', 'exact': 'Rep. Kevin Yoder', 'suffix': ' (R-Kan.), who is considered one of the most', 'offset': 2129, 'length': 16}], 'relevance': 0.2, 'confidence': {'statisticalfeature': '0.994', 'dblookup': '0.95', 'resolution': '0.0', 'aggregate': '0.995'}}
# mentioned 1 times
#
# Congress
# {'_typeGroup': 'entities', '_type': 'Organization', 'forenduserdisplay': 'false', 'name': 'Congress', 'organizationtype': 'governmental civilian', 'nationality': 'N/A', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Organization', 'permid': 'https://permid.org/1-404010', 'instances': [{'detection': '[one of the most vulnerable Republicans in ]Congress[. Hillary Clinton defeated Donald Trump among the]', 'prefix': 'one of the most vulnerable Republicans in ', 'exact': 'Congress', 'suffix': '. Hillary Clinton defeated Donald Trump among the', 'offset': 2216, 'length': 8}], 'relevance': 0.2}
# mentioned 1 times
#
# Kansas
# {'_typeGroup': 'entities', '_type': 'ProvinceOrState', 'forenduserdisplay': 'false', 'name': 'Kansas', '_typeReference': 'http://s.opencalais.com/1/type/em/e/ProvinceOrState', 'instances': [{'detection': '[lawyer seeking the Democratic nomination in ]Kansas[’ 3rd Congressional District.\n\nThe minute-long]', 'prefix': 'lawyer seeking the Democratic nomination in ', 'exact': 'Kansas', 'suffix': '’ 3rd Congressional District.\n\nThe minute-long', 'offset': 156, 'length': 6}, {'detection': '[for the chance to unseat Rep. Kevin Yoder (R-]Kan.[), who is considered one of the most vulnerable]', 'prefix': 'for the chance to unseat Rep. Kevin Yoder (R-', 'exact': 'Kan.', 'suffix': '), who is considered one of the most vulnerable', 'offset': 2149, 'length': 4}, {'detection': '[― even in a well-to-do swing seat in deep-red ]Kansas[.\n\nFollowing Sanders and Ocasio-Cortez’s rally]', 'prefix': '― even in a well-to-do swing seat in deep-red ', 'exact': 'Kansas', 'suffix': '.\n\nFollowing Sanders and Ocasio-Cortez’s rally', 'offset': 2813, 'length': 6}], 'relevance': 0.8, 'resolutions': [{'name': 'Kansas,United States', 'shortname': 'Kansas', 'latitude': '38.45', 'longitude': '-96.5333', 'containedbycountry': 'United States', 'rcscode': 'G:6D', 'permid': '100151'}]}
# mentioned 3 times
#
# Progressive Change Campaign Committee
# {'_typeGroup': 'entities', '_type': 'Organization', 'forenduserdisplay': 'false', 'name': 'Progressive Change Campaign Committee', 'organizationtype': 'N/A', 'nationality': 'N/A', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Organization', 'permid': 'https://permid.org/1-404010', 'instances': [{'detection': '[The ]Progressive Change Campaign Committee[ is funding an advertisement in support of Brent]', 'prefix': 'The ', 'exact': 'Progressive Change Campaign Committee', 'suffix': ' is funding an advertisement in support of Brent', 'offset': 4, 'length': 37}, {'detection': '[economic populism. Through its super PAC, the ]PCCC[ has purchased $30,000 worth of airtime to play]', 'prefix': 'economic populism. Through its super PAC, the ', 'exact': 'PCCC', 'suffix': ' has purchased $30,000 worth of airtime to play', 'offset': 389, 'length': 4}, {'detection': '[rally for Welder in the district, the ]PCCC[’s ad attempts to give Welder still more populist]', 'prefix': 'rally for Welder in the district, the ', 'exact': 'PCCC', 'suffix': '’s ad attempts to give Welder still more populist', 'offset': 2898, 'length': 4}, {'detection': '[alumnus of Sanders’ 2016 presidential run, the ]PCCC[ most closely associates itself with that other]', 'prefix': 'alumnus of Sanders’ 2016 presidential run, the ', 'exact': 'PCCC', 'suffix': ' most closely associates itself with that other', 'offset': 3054, 'length': 4}, {'detection': '[voters in red, purple, and blue districts,” ]PCCC[ co-founder Adam Green said of the group’s ad.]', 'prefix': 'voters in red, purple, and blue districts,” ', 'exact': 'PCCC', 'suffix': ' co-founder Adam Green said of the group’s ad.', 'offset': 3289, 'length': 4}], 'relevance': 0.8}
# mentioned 5 times
#
# official
# {'_typeGroup': 'entities', '_type': 'Position', 'forenduserdisplay': 'false', 'name': 'official', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position', 'instances': [{'detection': '[a union-side labor attorney and former campaign ]official[ for both Barack Obama and Sen. Bernie Sanders]', 'prefix': 'a union-side labor attorney and former campaign ', 'exact': 'official', 'suffix': ' for both Barack Obama and Sen. Bernie Sanders', 'offset': 888, 'length': 8}], 'relevance': 0.2}
# mentioned 1 times
#
# Alexandria Ocasio-Cortez
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Alexandria Ocasio-Cortez', 'persontype': 'N/A', 'nationality': 'N/A', 'confidencelevel': '0.946', 'firstname': 'Alexandria', 'lastname': 'Ocasio-Cortez', 'commonname': 'Alexandria Ocasio-Cortez', 'confidence': {'statisticalfeature': '0.97', 'dblookup': '0.0', 'resolution': '0.0', 'aggregate': '0.946'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[campaign rally in Kansas City where Sanders and ]Alexandria Ocasio-Cortez[, the Democratic nominee in New York’s 14th]', 'prefix': 'campaign rally in Kansas City where Sanders and ', 'exact': 'Alexandria Ocasio-Cortez', 'suffix': ', the Democratic nominee in New York’s 14th', 'offset': 1227, 'length': 24}, {'detection': '[seat in deep-red Kansas.\n\nFollowing Sanders and ]Ocasio-Cortez[’s rally for Welder in the district, the PCCC’s]', 'prefix': 'seat in deep-red Kansas.\n\nFollowing Sanders and ', 'exact': 'Ocasio-Cortez', 'suffix': '’s rally for Welder in the district, the PCCC’s', 'offset': 2844, 'length': 13}, {'detection': '[more populist momentum.\n\nAnd while Welder, like ]Ocasio-Cortez[, is an alumnus of Sanders’ 2016 presidential]', 'prefix': 'more populist momentum.\n\nAnd while Welder, like ', 'exact': 'Ocasio-Cortez', 'suffix': ', is an alumnus of Sanders’ 2016 presidential', 'offset': 2986, 'length': 13}], 'relevance': 0.2}
# mentioned 3 times
#
# Brent Welder
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Brent Welder', 'persontype': 'N/A', 'nationality': 'N/A', 'confidencelevel': '0.981', 'firstname': 'Brent', 'lastname': 'Welder', 'commonname': 'Brent Welder', 'confidence': {'statisticalfeature': '0.989', 'dblookup': '0.0', 'resolution': '0.0', 'aggregate': '0.981'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[is funding an advertisement in support of ]Brent Welder[, a progressive lawyer seeking the Democratic]', 'prefix': 'is funding an advertisement in support of ', 'exact': 'Brent Welder', 'suffix': ', a progressive lawyer seeking the Democratic', 'offset': 84, 'length': 12}, {'detection': '[entirely of a passionate segment from one of ]Welder[’s speeches, banks on voters’ appetites for]', 'prefix': 'entirely of a passionate segment from one of ', 'exact': 'Welder', 'suffix': '’s speeches, banks on voters’ appetites for', 'offset': 283, 'length': 6}, {'detection': '[politicians to keep it rigged in their favor,” ]Welder[ tells supporters at a July 20 rally featured in]', 'prefix': 'politicians to keep it rigged in their favor,” ', 'exact': 'Welder', 'suffix': ' tells supporters at a July 20 rally featured in', 'offset': 710, 'length': 6}, {'detection': '[here tonight to say, ‘Enough is enough!’”\n\n\n\n]Welder[, a union-side labor attorney and former campaign]', 'prefix': 'here tonight to say, ‘Enough is enough!’”\n\n\n\n', 'exact': 'Welder', 'suffix': ', a union-side labor attorney and former campaign', 'offset': 832, 'length': 6}, {'detection': '[affluent suburbs. The primary is next Tuesday.\n\n]Welder[ delivered the speech on which the ad is based at]', 'prefix': 'affluent suburbs. The primary is next Tuesday.\n\n', 'exact': 'Welder', 'suffix': ' delivered the speech on which the ad is based at', 'offset': 1113, 'length': 6}, {'detection': '[the primary is effectively a three-way race. ]Welder[’s top competitors are Tom Niermann, a centrist,]', 'prefix': 'the primary is effectively a three-way race. ', 'exact': 'Welder', 'suffix': '’s top competitors are Tom Niermann, a centrist,', 'offset': 1468, 'length': 6}, {'detection': '[ Davids is more liberal than Niermann, but unlike ]Welder[, is not running on Medicare for all and some]', 'prefix': ' Davids is more liberal than Niermann, but unlike ', 'exact': 'Welder', 'suffix': ', is not running on Medicare for all and some', 'offset': 1657, 'length': 6}, {'detection': '[win.\n\nBut national progressives stumping for ]Welder[ can’t pass up the opportunity to show that]', 'prefix': 'win.\n\nBut national progressives stumping for ', 'exact': 'Welder', 'suffix': ' can’t pass up the opportunity to show that', 'offset': 2657, 'length': 6}, {'detection': '[Sanders and Ocasio-Cortez’s rally for ]Welder[ in the district, the PCCC’s ad attempts to give]', 'prefix': 'Sanders and Ocasio-Cortez’s rally for ', 'exact': 'Welder', 'suffix': ' in the district, the PCCC’s ad attempts to give', 'offset': 2870, 'length': 6}, {'detection': '[in the district, the PCCC’s ad attempts to give ]Welder[ still more populist momentum.\n\nAnd while Welder,]', 'prefix': 'in the district, the PCCC’s ad attempts to give ', 'exact': 'Welder', 'suffix': ' still more populist momentum.\n\nAnd while Welder,', 'offset': 2925, 'length': 6}, {'detection': '[Welder still more populist momentum.\n\nAnd while ]Welder[, like Ocasio-Cortez, is an alumnus of Sanders’]', 'prefix': 'Welder still more populist momentum.\n\nAnd while ', 'exact': 'Welder', 'suffix': ', like Ocasio-Cortez, is an alumnus of Sanders’', 'offset': 2973, 'length': 6}, {'detection': '[tribune: Sen. Elizabeth Warren (D-Mass.). \n\n“]Brent Welder[ is the type of Elizabeth Warren-style, bold]', 'prefix': 'tribune: Sen. Elizabeth Warren (D-Mass.). \n\n“', 'exact': 'Brent Welder', 'suffix': ' is the type of Elizabeth Warren-style, bold', 'offset': 3163, 'length': 12}], 'relevance ...
# mentioned 12 times
#
# Bernie Sanders
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Bernie Sanders', 'persontype': 'political', 'nationality': 'N/A', 'confidencelevel': '0.999', 'firstname': 'Bernie', 'lastname': 'Sanders', 'commonname': 'Bernie Sanders', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[campaign official for both Barack Obama and ]Sen. Bernie Sanders[ (I-Vt.), is in a close contest for the]', 'prefix': 'campaign official for both Barack Obama and ', 'exact': 'Sen. Bernie Sanders', 'suffix': ' (I-Vt.), is in a close contest for the', 'offset': 923, 'length': 19}, {'detection': '[ at a massive campaign rally in Kansas City where ]Sanders[ and Alexandria Ocasio-Cortez, the Democratic]', 'prefix': ' at a massive campaign rally in Kansas City where ', 'exact': 'Sanders', 'suffix': ' and Alexandria Ocasio-Cortez, the Democratic', 'offset': 1215, 'length': 7}, {'detection': '[ 14th Congressional District, spoke in support of ]his[ candidacy.\n\nAlthough there are six Democratic]', 'prefix': ' 14th Congressional District, spoke in support of ', 'exact': 'his', 'suffix': ' candidacy.\n\nAlthough there are six Democratic', 'offset': 1339, 'length': 3}, {'detection': '[ district is not necessarily fertile ground for a ]Sanders[-style, class war battle cry. Local Democratic]', 'prefix': ' district is not necessarily fertile ground for a ', 'exact': 'Sanders', 'suffix': '-style, class war battle cry. Local Democratic', 'offset': 2456, 'length': 7}, {'detection': '[swing seat in deep-red Kansas.\n\nFollowing ]Sanders[ and Ocasio-Cortez’s rally for Welder in the]', 'prefix': 'swing seat in deep-red Kansas.\n\nFollowing ', 'exact': 'Sanders', 'suffix': ' and Ocasio-Cortez’s rally for Welder in the', 'offset': 2832, 'length': 7}, {'detection': '[Welder, like Ocasio-Cortez, is an alumnus of ]Sanders[’ 2016 presidential run, the PCCC most closely]', 'prefix': 'Welder, like Ocasio-Cortez, is an alumnus of ', 'exact': 'Sanders', 'suffix': '’ 2016 presidential run, the PCCC most closely', 'offset': 3018, 'length': 7}], 'relevance': 0.2, 'confidence': {'statisticalfeature': '0.999', 'dblookup': '0.95', 'resolution': '0.0', 'aggregate': '0.999'}}
# mentioned 6 times
#
# co-founder
# {'_typeGroup': 'entities', '_type': 'Position', 'forenduserdisplay': 'false', 'name': 'co-founder', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position', 'instances': [{'detection': '[ voters in red, purple, and blue districts,” PCCC ]co-founder[ Adam Green said of the group’s ad. “His message]', 'prefix': ' voters in red, purple, and blue districts,” PCCC ', 'exact': 'co-founder', 'suffix': ' Adam Green said of the group’s ad. “His message', 'offset': 3294, 'length': 10}], 'relevance': 0.2}
# mentioned 1 times
#
# Welder , a progressive lawyer
# {'_typeGroup': 'entities', '_type': 'Position', 'forenduserdisplay': 'false', 'name': 'Welder , a progressive lawyer', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position', 'instances': [{'detection': '[is funding an advertisement in support of Brent ]Welder, a progressive lawyer[ seeking the Democratic nomination in Kansas’ 3rd]', 'prefix': 'is funding an advertisement in support of Brent ', 'exact': 'Welder, a progressive lawyer', 'suffix': ' seeking the Democratic nomination in Kansas’ 3rd', 'offset': 90, 'length': 28}], 'relevance': 0.2}
# mentioned 1 times
#
# media market
# {'_typeGroup': 'entities', '_type': 'IndustryTerm', 'forenduserdisplay': 'false', 'name': 'media market', '_typeReference': 'http://s.opencalais.com/1/type/em/e/IndustryTerm', 'instances': [{'detection': '[morning and evening news in the Kansas City ]media market[, starting Thursday.\n\n“The wealthiest of the]', 'prefix': 'morning and evening news in the Kansas City ', 'exact': 'media market', 'suffix': ', starting Thursday.\n\n“The wealthiest of the', 'offset': 507, 'length': 12}], 'relevance': 0.2}
# mentioned 1 times
#
# Elizabeth Warren
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Elizabeth Warren', 'persontype': 'political', 'nationality': 'N/A', 'confidencelevel': '0.999', 'firstname': 'Elizabeth', 'lastname': 'Warren', 'commonname': 'Elizabeth Warren', 'confidence': {'statisticalfeature': '0.999', 'dblookup': '0.95', 'resolution': '0.0', 'aggregate': '0.999'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[itself with that other progressive tribune: ]Sen. Elizabeth Warren[ (D-Mass.). \n\n“Brent Welder is the type of]', 'prefix': 'itself with that other progressive tribune: ', 'exact': 'Sen. Elizabeth Warren', 'suffix': ' (D-Mass.). \n\n“Brent Welder is the type of', 'offset': 3127, 'length': 21}], 'relevance': 0.2}
# mentioned 1 times
#
# Welder , a union-side labor attorney
# {'_typeGroup': 'entities', '_type': 'Position', 'forenduserdisplay': 'false', 'name': 'Welder , a union-side labor attorney', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position', 'instances': [{'detection': '[here tonight to say, ‘Enough is enough!’”\n\n\n\n]Welder, a union-side labor attorney[ and former campaign official for both Barack]', 'prefix': 'here tonight to say, ‘Enough is enough!’”\n\n\n\n', 'exact': 'Welder, a union-side labor attorney', 'suffix': ' and former campaign official for both Barack', 'offset': 832, 'length': 35}], 'relevance': 0.2}
# mentioned 1 times
#
# Welder
# {'_typeGroup': 'entities', '_type': 'Position', 'forenduserdisplay': 'false', 'name': 'Welder', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position', 'instances': [{'detection': '[entirely of a passionate segment from one of ]Welder[’s speeches, banks on voters’ appetites for]', 'prefix': 'entirely of a passionate segment from one of ', 'exact': 'Welder', 'suffix': '’s speeches, banks on voters’ appetites for', 'offset': 283, 'length': 6}, {'detection': '[politicians to keep it rigged in their favor,” ]Welder[ tells supporters at a July 20 rally featured in]', 'prefix': 'politicians to keep it rigged in their favor,” ', 'exact': 'Welder', 'suffix': ' tells supporters at a July 20 rally featured in', 'offset': 710, 'length': 6}, {'detection': '[affluent suburbs. The primary is next Tuesday.\n\n]Welder[ delivered the speech on which the ad is based at]', 'prefix': 'affluent suburbs. The primary is next Tuesday.\n\n', 'exact': 'Welder', 'suffix': ' delivered the speech on which the ad is based at', 'offset': 1113, 'length': 6}, {'detection': '[the primary is effectively a three-way race. ]Welder[’s top competitors are Tom Niermann, a centrist,]', 'prefix': 'the primary is effectively a three-way race. ', 'exact': 'Welder', 'suffix': '’s top competitors are Tom Niermann, a centrist,', 'offset': 1468, 'length': 6}, {'detection': '[ Davids is more liberal than Niermann, but unlike ]Welder[, is not running on Medicare for all and some]', 'prefix': ' Davids is more liberal than Niermann, but unlike ', 'exact': 'Welder', 'suffix': ', is not running on Medicare for all and some', 'offset': 1657, 'length': 6}, {'detection': '[win.\n\nBut national progressives stumping for ]Welder[ can’t pass up the opportunity to show that]', 'prefix': 'win.\n\nBut national progressives stumping for ', 'exact': 'Welder', 'suffix': ' can’t pass up the opportunity to show that', 'offset': 2657, 'length': 6}, {'detection': '[Sanders and Ocasio-Cortez’s rally for ]Welder[ in the district, the PCCC’s ad attempts to give]', 'prefix': 'Sanders and Ocasio-Cortez’s rally for ', 'exact': 'Welder', 'suffix': ' in the district, the PCCC’s ad attempts to give', 'offset': 2870, 'length': 6}, {'detection': '[in the district, the PCCC’s ad attempts to give ]Welder[ still more populist momentum.\n\nAnd while Welder,]', 'prefix': 'in the district, the PCCC’s ad attempts to give ', 'exact': 'Welder', 'suffix': ' still more populist momentum.\n\nAnd while Welder,', 'offset': 2925, 'length': 6}, {'detection': '[Welder still more populist momentum.\n\nAnd while ]Welder[, like Ocasio-Cortez, is an alumnus of Sanders’]', 'prefix': 'Welder still more populist momentum.\n\nAnd while ', 'exact': 'Welder', 'suffix': ', like Ocasio-Cortez, is an alumnus of Sanders’', 'offset': 2973, 'length': 6}], 'relevance': 0.8}
# mentioned 9 times
#
# The primary
# {'_typeGroup': 'entities', '_type': 'PoliticalEvent', 'forenduserdisplay': 'false', 'name': 'The primary', 'politicaleventtype': 'Voting', '_typeReference': 'http://s.opencalais.com/1/type/em/e/PoliticalEvent', 'instances': [{'detection': '[City and many of its most affluent suburbs. ]The primary[ is next Tuesday.\n\nWelder delivered the speech on]', 'prefix': 'City and many of its most affluent suburbs. ', 'exact': 'The primary', 'suffix': ' is next Tuesday.\n\nWelder delivered the speech on', 'offset': 1083, 'length': 11}, {'detection': '[ six Democratic candidates, poll watchers believe ]the primary[ is effectively a three-way race. Welder’s top]', 'prefix': ' six Democratic candidates, poll watchers believe ', 'exact': 'the primary', 'suffix': ' is effectively a three-way race. Welder’s top', 'offset': 1423, 'length': 11}], 'relevance': 0.2}
# mentioned 2 times
#
# Tom Niermann
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Tom Niermann', 'persontype': 'N/A', 'nationality': 'N/A', 'confidencelevel': '0.983', 'firstname': 'Tom', 'lastname': 'Niermann', 'commonname': 'Tom Niermann', 'confidence': {'statisticalfeature': '0.989', 'dblookup': '0.0', 'resolution': '0.0', 'aggregate': '0.983'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[a three-way race. Welder’s top competitors are ]Tom Niermann[, a centrist, private-school history teacher, and]', 'prefix': 'a three-way race. Welder’s top competitors are ', 'exact': 'Tom Niermann', 'suffix': ', a centrist, private-school history teacher, and', 'offset': 1497, 'length': 12}, {'detection': '[attorney. Davids is more liberal than ]Niermann[, but unlike Welder, is not running on Medicare]', 'prefix': 'attorney. Davids is more liberal than ', 'exact': 'Niermann', 'suffix': ', but unlike Welder, is not running on Medicare', 'offset': 1636, 'length': 8}, {'detection': '[Democratic officials, who are mostly backing ]Niermann[, see moderation as the surest ticket to a]', 'prefix': 'Democratic officials, who are mostly backing ', 'exact': 'Niermann', 'suffix': ', see moderation as the surest ticket to a', 'offset': 2544, 'length': 8}], 'relevance': 0.2}
# mentioned 3 times
#
# MMA
# {'_typeGroup': 'entities', '_type': 'Organization', 'forenduserdisplay': 'false', 'name': 'MMA', 'organizationtype': 'political party', 'nationality': 'N/A', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Organization', 'permid': 'https://permid.org/1-404010', 'instances': [{'detection': '[story as a Native American lesbian and amateur ]MMA[ fighter, raised by a single Army veteran]', 'prefix': 'story as a Native American lesbian and amateur ', 'exact': 'MMA', 'suffix': ' fighter, raised by a single Army veteran', 'offset': 2029, 'length': 3}], 'relevance': 0.2}
# mentioned 1 times
#
# Sharice Davids
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Sharice Davids', 'persontype': 'N/A', 'nationality': 'N/A', 'confidencelevel': '0.99', 'firstname': 'Sharice', 'lastname': 'Davids', 'commonname': 'Sharice Davids', 'confidence': {'statisticalfeature': '0.994', 'dblookup': '0.0', 'resolution': '0.0', 'aggregate': '0.99'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[a centrist, private-school history teacher, and ]Sharice Davids[, an EMILY’S List-backed attorney. Davids is more]', 'prefix': 'a centrist, private-school history teacher, and ', 'exact': 'Sharice Davids', 'suffix': ', an EMILY’S List-backed attorney. Davids is more', 'offset': 1559, 'length': 14}, {'detection': '[ Sharice Davids, an EMILY’S List-backed attorney. ]Davids[ is more liberal than Niermann, but unlike]', 'prefix': ' Sharice Davids, an EMILY’S List-backed attorney. ', 'exact': 'Davids', 'suffix': ' is more liberal than Niermann, but unlike', 'offset': 1608, 'length': 6}, {'detection': '[for all and some other progressive priorities. (]Davids[ told The Intercept that she would vote for a]', 'prefix': 'for all and some other progressive priorities. (', 'exact': 'Davids', 'suffix': ' told The Intercept that she would vote for a', 'offset': 1740, 'length': 6}, {'detection': '[priorities. (Davids told The Intercept that ]she[ would vote for a Medicare-for-all bill if it]', 'prefix': 'priorities. (Davids told The Intercept that ', 'exact': 'she', 'suffix': ' would vote for a Medicare-for-all bill if it', 'offset': 1771, 'length': 3}, {'detection': '[bill if it came up for a vote, but that ]she[ is focusing on interim steps given how difficult]', 'prefix': 'bill if it came up for a vote, but that ', 'exact': 'she', 'suffix': ' is focusing on interim steps given how difficult', 'offset': 1849, 'length': 3}, {'detection': '[it will be to achieve in the near term.) ]She[ is running heavily on her personal story as a]', 'prefix': 'it will be to achieve in the near term.) ', 'exact': 'She', 'suffix': ' is running heavily on her personal story as a', 'offset': 1943, 'length': 3}, {'detection': '[in the near term.) She is running heavily on ]her[ personal story as a Native American lesbian and]', 'prefix': 'in the near term.) She is running heavily on ', 'exact': 'her', 'suffix': ' personal story as a Native American lesbian and', 'offset': 1969, 'length': 3}, {'detection': '[version of this story incorrectly referred to ]Sharice Davids[ as an Army veteran. Her mother served in the]', 'prefix': 'version of this story incorrectly referred to ', 'exact': 'Sharice Davids', 'suffix': ' as an Army veteran. Her mother served in the', 'offset': 3575, 'length': 14}, {'detection': '[referred to Sharice Davids as an Army veteran. ]Her[ mother served in the Army. It also incorrectly]', 'prefix': 'referred to Sharice Davids as an Army veteran. ', 'exact': 'Her', 'suffix': ' mother served in the Army. It also incorrectly', 'offset': 3610, 'length': 3}, {'detection': '[in the Army. It also incorrectly claimed that ]Davids[ does not support Medicare for all. She has said]', 'prefix': 'in the Army. It also incorrectly claimed that ', 'exact': 'Davids', 'suffix': ' does not support Medicare for all. She has said', 'offset': 3674, 'length': 6}, {'detection': '[that Davids does not support Medicare for all. ]She[ has said she would vote for it if it came up.]', 'prefix': 'that Davids does not support Medicare for all. ', 'exact': 'She', 'suffix': ' has said she would vote for it if it came up.', 'offset': 3716, 'length': 3}, {'detection': '[does not support Medicare for all. She has said ]she[ would vote for it if it came up.]', 'prefix': 'does not support Medicare for all. She has said ', 'exact': 'she', 'suffix': ' would vote for it if it came up.', 'offset': 3729, 'length': 3}], 'relevance': 0.2}
# mentioned 12 times
#
# Adam Green
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Adam Green', 'persontype': 'N/A', 'nationality': 'N/A', 'confidencelevel': '0.999', 'firstname': 'Adam', 'lastname': 'Green', 'commonname': 'Adam Green', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[purple, and blue districts,” PCCC co-founder ]Adam Green[ said of the group’s ad. “His message of]', 'prefix': 'purple, and blue districts,” PCCC co-founder ', 'exact': 'Adam Green', 'suffix': ' said of the group’s ad. “His message of', 'offset': 3305, 'length': 10}, {'detection': '[co-founder Adam Green said of the group’s ad. “]His[ message of challenging corporate power over our]', 'prefix': 'co-founder Adam Green said of the group’s ad. “', 'exact': 'His', 'suffix': ' message of challenging corporate power over our', 'offset': 3341, 'length': 3}], 'relevance': 0.2, 'confidence': {'statisticalfeature': '0.998', 'dblookup': '0.95', 'resolution': '0.0', 'aggregate': '0.999'}}
# mentioned 2 times
#
# Hillary Clinton
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Hillary Clinton', 'persontype': 'N/A', 'nationality': 'N/A', 'confidencelevel': '0.98', 'firstname': 'Hillary', 'lastname': 'Clinton', 'commonname': 'Hillary Clinton', 'confidence': {'statisticalfeature': '0.97', 'dblookup': '0.95', 'resolution': '0.0', 'aggregate': '0.98'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[of the most vulnerable Republicans in Congress. ]Hillary Clinton[ defeated Donald Trump among the district’s]', 'prefix': 'of the most vulnerable Republicans in Congress. ', 'exact': 'Hillary Clinton', 'suffix': ' defeated Donald Trump among the district’s', 'offset': 2226, 'length': 15}], 'relevance': 0.2}
# mentioned 1 times
#
# Elizabeth Warren-style
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Elizabeth Warren-style', 'persontype': 'N/A', 'nationality': 'N/A', 'confidencelevel': '0.95', 'firstname': 'Elizabeth', 'lastname': 'Warren-style', 'commonname': 'Elizabeth Warren-style', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[ Warren (D-Mass.). \n\n“Brent Welder is the type of ]Elizabeth Warren-style[, bold progressive that excites voters in red,]', 'prefix': ' Warren (D-Mass.). \n\n“Brent Welder is the type of ', 'exact': 'Elizabeth Warren-style', 'suffix': ', bold progressive that excites voters in red,', 'offset': 3191, 'length': 22}], 'relevance': 0.2, 'confidence': {'statisticalfeature': '0.97', 'dblookup': '0.0', 'resolution': '0.0', 'aggregate': '0.95'}}
# mentioned 1 times
#
# Barack Obama
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Barack Obama', 'persontype': 'N/A', 'nationality': 'N/A', 'confidencelevel': '0.999', 'firstname': 'Barack', 'lastname': 'Obama', 'commonname': 'Barack Obama', 'confidence': {'statisticalfeature': '0.999', 'dblookup': '0.95', 'resolution': '0.0', 'aggregate': '0.999'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[attorney and former campaign official for both ]Barack Obama[ and Sen. Bernie Sanders (I-Vt.), is in a close]', 'prefix': 'attorney and former campaign official for both ', 'exact': 'Barack Obama', 'suffix': ' and Sen. Bernie Sanders (I-Vt.), is in a close', 'offset': 906, 'length': 12}], 'relevance': 0.2}
# mentioned 1 times
#
# centrist, private-school history teacher
# {'_typeGroup': 'entities', '_type': 'Position', 'forenduserdisplay': 'false', 'name': 'centrist, private-school history teacher', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position', 'instances': [{'detection': '[ race. Welder’s top competitors are Tom Niermann, ]a centrist, private-school history teacher[, and Sharice Davids, an EMILY’S List-backed]', 'prefix': ' race. Welder’s top competitors are Tom Niermann, ', 'exact': 'a centrist, private-school history teacher', 'suffix': ', and Sharice Davids, an EMILY’S List-backed', 'offset': 1511, 'length': 42}], 'relevance': 0.2}
# mentioned 1 times
#
# List-backed attorney
# {'_typeGroup': 'entities', '_type': 'Position', 'forenduserdisplay': 'false', 'name': 'List-backed attorney', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position', 'instances': [{'detection': '[history teacher, and Sharice Davids, an EMILY’S ]List-backed attorney[. Davids is more liberal than Niermann, but]', 'prefix': 'history teacher, and Sharice Davids, an EMILY’S ', 'exact': 'List-backed attorney', 'suffix': '. Davids is more liberal than Niermann, but', 'offset': 1586, 'length': 20}], 'relevance': 0.2}
# mentioned 1 times
#
# Army
# {'_typeGroup': 'entities', '_type': 'Organization', 'forenduserdisplay': 'false', 'name': 'Army', 'organizationtype': 'governmental military', 'nationality': 'N/A', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Organization', 'permid': 'https://permid.org/1-404010', 'instances': [{'detection': '[and amateur MMA fighter, raised by a single ]Army[ veteran mom.\n\nThe Democrats are vying for the]', 'prefix': 'and amateur MMA fighter, raised by a single ', 'exact': 'Army', 'suffix': ' veteran mom.\n\nThe Democrats are vying for the', 'offset': 2061, 'length': 4}, {'detection': '[incorrectly referred to Sharice Davids as an ]Army[ veteran. Her mother served in the Army. It also]', 'prefix': 'incorrectly referred to Sharice Davids as an ', 'exact': 'Army', 'suffix': ' veteran. Her mother served in the Army. It also', 'offset': 3596, 'length': 4}, {'detection': '[as an Army veteran. Her mother served in the ]Army[. It also incorrectly claimed that Davids does]', 'prefix': 'as an Army veteran. Her mother served in the ', 'exact': 'Army', 'suffix': '. It also incorrectly claimed that Davids does', 'offset': 3635, 'length': 4}], 'relevance': 0.2}
# mentioned 3 times
#
# New York
# {'_typeGroup': 'entities', '_type': 'City', 'forenduserdisplay': 'true', 'name': 'New York', '_typeReference': 'http://s.opencalais.com/1/type/em/e/City', 'instances': [{'detection': '[Ocasio-Cortez, the Democratic nominee in ]New York[’s 14th Congressional District, spoke in support]', 'prefix': 'Ocasio-Cortez, the Democratic nominee in ', 'exact': 'New York', 'suffix': '’s 14th Congressional District, spoke in support', 'offset': 1279, 'length': 8}], 'relevance': 0.2, 'resolutions': [{'name': 'New York City,New York,United States', 'shortname': 'New York City', 'latitude': '40.7142', 'longitude': '-74.0064', 'containedbystate': 'New York', 'containedbycountry': 'United States', 'rcscode': 'G:7T'}]}
# mentioned 1 times
#
# Massachusetts
# {'_typeGroup': 'entities', '_type': 'ProvinceOrState', 'forenduserdisplay': 'false', 'name': 'Massachusetts', 'resolutions': [{'name': 'Massachusetts,United States', 'shortname': 'Massachusetts', 'latitude': '42.3', 'longitude': '-71.8', 'containedbycountry': 'United States', 'rcscode': 'G:3K', 'permid': '100180'}], '_typeReference': 'http://s.opencalais.com/1/type/em/e/ProvinceOrState', 'instances': [{'detection': '[progressive tribune: Sen. Elizabeth Warren (D-]Mass.[). \n\n“Brent Welder is the type of Elizabeth]', 'prefix': 'progressive tribune: Sen. Elizabeth Warren (D-', 'exact': 'Mass.', 'suffix': '). \n\n“Brent Welder is the type of Elizabeth', 'offset': 3152, 'length': 5}], 'relevance': 0.2}
# mentioned 1 times
#
# Donald Trump
# {'_typeGroup': 'entities', '_type': 'Person', 'forenduserdisplay': 'true', 'name': 'Donald Trump', 'persontype': 'entertainment', 'nationality': 'N/A', 'confidencelevel': '0.998', 'firstname': 'Donald', 'lastname': 'Trump', 'commonname': 'Donald Trump', 'resolutions': [{'name': 'Donald John Trump', 'personid': '55206', 'paid': '34413176227', 'officerid': ['1309208', '55206', '650373'], 'commonname': 'Donald Trump', 'score': 0.87165964}], 'confidence': {'statisticalfeature': '0.996', 'dblookup': '0.95', 'resolution': '0.87165964', 'aggregate': '0.998'}, '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person', 'permid': 'https://permid.org/1-404011', 'instances': [{'detection': '[in Congress. Hillary Clinton defeated ]Donald Trump[ among the district’s voters by 1 percentage]', 'prefix': 'in Congress. Hillary Clinton defeated ', 'exact': 'Donald Trump', 'suffix': ' among the district’s voters by 1 percentage', 'offset': 2251, 'length': 12}, {'detection': '[by 1 percentage point; national Democrats put ]Trump[’s approval rating there at about 35]', 'prefix': 'by 1 percentage point; national Democrats put ', 'exact': 'Trump', 'suffix': '’s approval rating there at about 35', 'offset': 2338, 'length': 5}], 'relevance': 0.2}
# mentioned 2 times
#
# Medicare
# {'_typeGroup': 'entities', '_type': 'Organization', 'forenduserdisplay': 'false', 'name': 'Medicare', 'organizationtype': 'governmental civilian', 'nationality': 'N/A', '_typeReference': 'http://s.opencalais.com/1/type/em/e/Organization', 'permid': 'https://permid.org/1-404010', 'instances': [{'detection': '[Niermann, but unlike Welder, is not running on ]Medicare[ for all and some other progressive priorities.]', 'prefix': 'Niermann, but unlike Welder, is not running on ', 'exact': 'Medicare', 'suffix': ' for all and some other progressive priorities.', 'offset': 1683, 'length': 8}, {'detection': '[told The Intercept that she would vote for a ]Medicare[-for-all bill if it came up for a vote, but that]', 'prefix': 'told The Intercept that she would vote for a ', 'exact': 'Medicare', 'suffix': '-for-all bill if it came up for a vote, but that', 'offset': 1792, 'length': 8}, {'detection': '[over our political system and bold ideas like ]Medicare[ For All is exactly what will maximize a]', 'prefix': 'over our political system and bold ideas like ', 'exact': 'Medicare', 'suffix': ' For All is exactly what will maximize a', 'offset': 3430, 'length': 8}, {'detection': '[ incorrectly claimed that Davids does not support ]Medicare[ for all. She has said she would vote for it if]', 'prefix': ' incorrectly claimed that Davids does not support ', 'exact': 'Medicare', 'suffix': ' for all. She has said she would vote for it if', 'offset': 3698, 'length': 8}], 'relevance': 0.2}
# mentioned 4 times

# %% [markdown]
# At this point, the next step is to synthesize these results into a search querry

# %%
tags = []
for topic in topics: 
    if c[topic]['_typeGroup'] == "entities":
        new_entity = {}
        new_entity['name'] = c[topic]['name']
        new_entity['mentions'] = len(c[topic]['instances'])
        new_entity['type'] = c[topic]['_type']
        if(new_entity['type'] == "Person"):
#             print(new_entity['name'])
            new_entity['commonname'] = c[topic]['commonname']
        else:
            new_entity['commonname'] = ""
        tags.append(new_entity)

# %%
import pandas as pd

df = pd.DataFrame(tags)
df
# Out:
#                   commonname  mentions  \
# 0                                    3
# 1                Kevin Yoder         1
# 2                                    1
# 3                                    3
# 4                                    5
# 5                                    1
# 6   Alexandria Ocasio-Cortez         3
# 7               Brent Welder        12
# 8             Bernie Sanders         6
# 9                                    1
# 10                                   1
# 11                                   1
# 12          Elizabeth Warren         1
# 13                                   1
# 14                                   9
# 15                                   2
# 16              Tom Niermann         3
# 17                                   1
# 18            Sharice Davids        12
# 19                Adam Green         2
# 20           Hillary Clinton         1
# 21    Elizabeth Warren-style         1
# 22              Barack Obama         1
# 23                                   1
# 24                                   1
# 25                                   3
# 26                                   1
# 27                                   1
# 28              Donald Trump         2
# 29                                   4
#
#                                         name             type
# 0                                Kansas City             City
# 1                                Kevin Yoder           Person
# 2                                   Congress     Organization
# 3                                     Kansas  ProvinceOrState
# 4      Progressive Change Campaign Committee     Organization
# 5                                   official         Position
# 6                   Alexandria Ocasio-Cortez           Person
# 7                               Brent Welder           Person
# 8                             Bernie Sanders           Person
# 9                                 co-founder         Position
# 10             Welder , a progressive lawyer         Position
# 11                              media market     IndustryTerm
# 12                          Elizabeth Warren           Person
# 13      Welder , a union-side labor attorney         Position
# 14                                    Welder         Position
# 15                               The primary   PoliticalEvent
# 16                              Tom Niermann           Person
# 17                                       MMA     Organization
# 18                            Sharice Davids           Person
# 19                                Adam Green           Person
# 20                           Hillary Clinton           Person
# 21                    Elizabeth Warren-style           Person
# 22                              Barack Obama           Person
# 23  centrist, private-school history teacher         Position
# 24                      List-backed attorney         Position
# 25                                      Army     Organization
# 26                                  New York             City
# 27                             Massachusetts  ProvinceOrState
# 28                              Donald Trump           Person
# 29                                  Medicare     Organization

# %%
df[df['mentions'] > df['mentions'].mean()]
# Out:
#                   commonname  mentions                                   name  \
# 0                                    3                            Kansas City
# 3                                    3                                 Kansas
# 4                                    5  Progressive Change Campaign Committee
# 6   Alexandria Ocasio-Cortez         3               Alexandria Ocasio-Cortez
# 7               Brent Welder        12                           Brent Welder
# 8             Bernie Sanders         6                         Bernie Sanders
# 14                                   9                                 Welder
# 16              Tom Niermann         3                           Tom Niermann
# 18            Sharice Davids        12                         Sharice Davids
# 25                                   3                                   Army
# 29                                   4                               Medicare
#
#                type
# 0              City
# 3   ProvinceOrState
# 4      Organization
# 6            Person
# 7            Person
# 8            Person
# 14         Position
# 16           Person
# 18           Person
# 25     Organization
# 29     Organization

# %%
# Select all people who were mentioned more than the mean number of mentions per person
POI = list(df[(df["type"] == "Person") & (df['mentions'] > df[df['type'] =='Person']['mentions'].mean())]['commonname'])

# Do we want to search full names, or just last names?
query = " AND ".join(POI)
query = query.replace(" ", "%20")

queryURL = "https://archive.org/details/tv?q="+query
print(queryURL)
# Out:
# https://archive.org/details/tv?q=Brent%20Welder%20AND%20Bernie%20Sanders%20AND%20Sharice%20Davids
